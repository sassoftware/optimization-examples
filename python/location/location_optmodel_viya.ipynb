# %% [markdown]
# # Facility Location with Regions
#
# Based on Example 14.3 from the SAS Optimization documentation: https://go.documentation.sas.com/doc/en/pgmsascdc/default/casmopt/casmopt_milpsolver_examples03.htm
#
# For a set of customers and sites, choose which sites to build such that:
# - We minimize the sum of the distances between customers and their assigned sites and the building costs of sites
# - The capacity for each site is not exceeded
# - Sites and customers are in same region

# %% [markdown]
# #### Mixed Integer Linear Programming Formulation
#
# $ \begin{array}{llllll}
# \min & \displaystyle \sum _{i \in L} \displaystyle \sum _{j \in F} c_{ij} x_{ij} &+& \displaystyle \sum _{j \in F} f_ j y_ j \\
# \text{s.t.} & \displaystyle \sum _{j \in F} x_{ij} & = & 1 & \forall i \in L & \text{(assign\_def)} \\
# & \displaystyle \sum _{i \in L} d_ i x_{ij} & \leq & Cy_ j & \forall j \in F & \text{(capacity)} \\
# & x_{ij} & = & 0 & \forall i,j \text{ if } r_i \ne r_j & \text{(region\_con)} \\
# \\
# & x_{ij} \in \{ 0,1\} & & & \forall i \in L, j \in F \\
# & y_{j} \in \{ 0,1\} & & & \forall j \in F
# \end{array}
# $

# %% [markdown]
# #### Input Data
#
# For the input data we have a comma-separated value (CSV) file with all cities in Germany with more than 50,000 inhabitants retrieved from the German Federal Office of Statistics (www.destatis.de) that also includes geo locations of the cities for plotting. The following code reads the file and plots the data on a map.

# %%
import folium
import pandas as pd

# Read the input data and make sure the numbers are all parsed correctly, then print the top of the DataFrame
indata = pd.read_csv('cities_germany.csv', sep=';', decimal=',')
indata["size"] = pd.to_numeric(indata["size"].str.replace(" ", ""), errors='coerce')
indata["density"] = pd.to_numeric(indata["density"].str.replace(" ", ""), errors='coerce')
print(indata)

# Display the cities on a map of Germany
map_input = folium.Map(location=(52, 9), zoom_start=6)
for index, row in indata.iterrows():
    folium.Marker(location=[row["lat"], row["lon"]], tooltip=f'{row["name"]}<br>Size: {row["size"]}<br>Density: {row["density"]}').add_to(map_input)
display(map_input)
# Out:
#      state                            name     size  density  zipcode  \
# 0       11                   Berlin, Stadt  3755251     4214    10178
# 1        2   Hamburg, Freie und Hansestadt  1892122     2506    20095
# 2        9       München, Landeshauptstadt  1512491     4868    80331
# 3        5                     Köln, Stadt  1084831     2678    50667
# 4        6        Frankfurt am Main, Stadt   773068     3113    60311
# ..     ...                             ...      ...      ...      ...
# 190      1                 Elmshorn, Stadt    50772     2377    25335
# 191      3                    Emden, Stadt    50535      450    26721
# 192      3                   Goslar, Stadt    50203      306    38640
# 193      5                  Willich, Stadt    50144      740    47877
# 194      8  Heidenheim an der Brenz, Stadt    50025      467    89522
#
#            lon        lat  type
# 0    13.405538  52.517670     1
# 1     9.996970  53.550678     1
# 2    11.575997  48.137683     1
# 3     6.957068  50.938107     1
# 4     8.682433  50.110880     1
# ..         ...        ...   ...
# 190   9.655259  53.754958     2
# 191   7.205946  53.370558     2
# 192  10.429312  51.906508     2
# 193   6.550043  51.262542     2
# 194  10.154639  48.677736     2
#
# [195 rows x 8 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d27a3750ea1b9ca1cdbc3b747065ec5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d27a3750ea1b9ca1cdbc3b747065ec5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d27a3750ea1b9ca1cdbc3b747065ec5 = L.map(
#                 &quot;map_4d27a3750ea1b9ca1cdbc3b747065ec5&quot;,
#                 {
#                     center: [52.0, 9.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aeedefbb5542d823034e1c7bfe93092c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_aeedefbb5542d823034e1c7bfe93092c.addTo(map_4d27a3750ea1b9ca1cdbc3b747065ec5);
#
#
#             var marker_7ccf0bdd81205e24681f464de0ab0c2b = L.marker(
#                 [52.51767, 13.405538],
#                 {}
#             ).addTo(map_4d27a3750ea1b9ca1cdbc3b747065ec5);
#
#
#             marker_7ccf0bdd81205e24681f464de0ab0c2b.bindTooltip(
#                 `&lt;div&gt;
#                      Berlin, Stadt&lt;br&gt;Size: 3755251&lt;br&gt;Density: 4214
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_32c6bf84bea36ec2f89b22450cf79766 = L.marker(
#                 [53.550678, 9.99697],
#                 {}
#             ).addTo(map_4d27a3750ea1b9ca1cdbc3b747065ec5);
#
#
#             marker_32c6bf84bea36ec2f89b22450cf79766.bindTooltip(
#                 `&lt;div&gt;
#                      Hamburg, Freie und Hansestadt&lt;br&gt;Size: 1892122&lt;br&gt;Density: 2506
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_64ae264d28756fe0874a06dbcaaa4120 = L.marker(
#                 [48.137683, 11.575997],
#                 {}
#             ).addTo(map_4d27a3750ea1b9ca1cdbc3b747065ec5);
#
#
#             marker_64ae264d28756fe0874a06dbcaaa4120.bindTooltip(
#                 `&lt;div&gt;
#                      München, Landeshauptstadt&lt;br&gt;Size: 1512491&lt;br&gt;Density: 4868
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0733a304b2cab1fc78348a9d181ad0de = L.marker(
#                 [50.938107, 6.957068],
#                 {}
#             ).addTo(map_4d27a3750ea1b9ca1cdbc3b747065ec5);
#
#
#             marker_0733a304b2cab1fc78348a9d181ad0de.bindTooltip(
#                 `&lt;div&gt;
#                      Köln, Stadt&lt;br&gt;Size: 1084831&lt;br&gt;Density: 2678
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_68f54c7d000ba11f15aad19af5e1d033 = L.marker(
#                 [50.11088, 8.682433],
#                 {}
#             ).addTo(map_4d27a3750ea1b9ca1cdbc3b747065ec5);
#
#
#             marker_68f54c7d000ba11f15aad19af5e1d033.bindTooltip(
#                 `&lt;div&gt;
#                      Frankfurt am Main, Stadt&lt;br&gt;Size: 773068&lt;br&gt;Density: 3113
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8dfaa5b1ef56ac0ec9fd1733115407ce = L.marker(
#                 [48.775817, 9.177734],
#                 {}
#             ).addTo(map_4d27a3750ea1b9ca1cdbc3b747065ec5);
#
#
#             marker_8dfaa5b1ef56ac0ec9fd1733115407ce.bindTooltip(
#                 `&lt;div&gt;
#                      Stuttgart, Landeshauptstadt&lt;br&gt;Size: 632865&lt;br&gt;Density: 3052
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b1b218bc45e081b5376a3ac992a147f4 = L.marker(
#                 [51.22422, 6.780068],
#                 {}
#             ).addTo(map_4d27a3750ea1b9ca1cdbc3b747065ec5);
#
#
#             marker_b1b218bc45e081b5376a3ac992a147f4.bindTooltip(
#                 `&lt;div&gt;
#                      Düsseldorf, Stadt&lt;br&gt;Size: 629047&lt;br&gt;Density: 2893
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d3d9ab2b8218f0a793291b996f6f749d = L.marker(
#                 [51.338288, 12.377931],
#                 {}
#             ).addTo(map_4d27a3750ea1b9ca1cdbc3b747065ec5);
#
#
#             marker_d3d9ab2b8218f0a793291b996f6f749d.bindTooltip(
#                 `&lt;div&gt;
#                      Leipzig, Stadt&lt;br&gt;Size: 616093&lt;br&gt;Density: 2069
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_54cdd7eed7feb50283ac1efb3883f3dd = L.marker(
#                 [51.514171, 7.464165],
#                 {}
#             ).addTo(map_4d27a3750ea1b9ca1cdbc3b747065ec5);
#
#
#             marker_54cdd7eed7feb50283ac1efb3883f3dd.bindTooltip(
#                 `&

# %% [markdown]
# #### Connecting to SAS Viya
#
# The connection options are provided in "cas.py" in the same directory. The following code establishes a connection and creates a SAS data set from the Pandas data frame.

# %%
import swat
from cas import cas_options

sas = swat.CAS(**cas_options)
_ = sas.upload_frame(indata, casout={"name": "indata", "replace": True})
# Out:
# NOTE: Cloud Analytic Services made the uploaded file available as table INDATA in caslib CASUSER(phchri).
# NOTE: The table INDATA has been created in caslib CASUSER(phchri) from binary data uploaded to Cloud Analytic Services.

# %% [markdown]
# #### Defining and Solving the Optimization Problem with OPTMODEL
#
# In this specific example, every customer location (city) can also be a site. The demand of each city is its size while we use the density as the cost to build a site. This means that building a site in a less densely populated cities is preferable. This leads to an interesting optimization problem for demonstration purposes but has no real-world meaning.
#
# First we define the OPTMODEL code that we want to execute. Then it is sent to SAS.

# %%
# Define the model in OPTMODEL
optmodel_code = """
   /* Define set of sites, only need one set since all sites are also customers */
   set <str> SITES;

   /* Latitude and Longitude for SITES */
   num lat {SITES};
   num lon {SITES};

   /* Capacity of each site */
   num C = 5000000;

   /* Other parameters */
   num demand {SITES};
   num cost {SITES};
   num region {SITES};

   /* Define a set of tuples for all possible assignments */
   set PAIRS = {i in SITES, j in SITES};

   /* Compute distances between sites */
   num distance {<i,j> in PAIRS}
       = round(geodist(lat[i], lon[i], lat[j], lon[j], 'K'));

   /* Read the data */
   read data indata into SITES=[name] lat lon region=state demand=size cost=density;

   /* Create variables */
   var Assign {PAIRS} binary;
   var Build {SITES} binary;

   /* Define objective function */
   min TotalCost
       = sum {<i,j> in PAIRS} distance[i,j] * Assign[i,j]
         + sum {j in SITES} cost[j] * Build[j];

   /* Each site needs to be assigned to exactly once */
   con assign_def {i in SITES}:
      sum {<(i),j> in PAIRS} Assign[i,j] = 1;

   /* Each site we build can handle at most C demand */
   con capacity {j in SITES}:
      sum {<i,(j)> in PAIRS} demand[i] * Assign[i,j] <= C * Build[j];

   /* Solve with the MILP solver */
   solve;

   /* Create output data sets */
   create data assignments from
        [customer site]={<i,j> in PAIRS: Assign[i,j] > 0.5}
        lat1=lat[i] lon1=lon[i] lat2=lat[j] lon2=lon[j] distance[i,j];
   create data sites from
        [site]={j in SITES: Build[j] > 0.5}
            name=j lat[j] lon[j] cost[j];
"""
# Submit the model to SAS
sas.loadactionset("optimization")

_ = sas.runOptmodel(optmodel_code)

# Create output data frames to plot the solution
assignments = sas.CASTable("assignments")
sites = sas.CASTable("sites")
# Out:
# NOTE: Added action set 'optimization'.
# NOTE: There were 195 rows read from table 'INDATA' in caslib 'CASUSER(phchri)'.
# NOTE: Problem generation will use 16 threads.
# NOTE: The problem has 38220 variables (0 free, 0 fixed).
# NOTE: The problem has 38220 binary and 0 integer variables.
# NOTE: The problem has 390 linear constraints (195 LE, 195 EQ, 0 GE, 0 range).
# NOTE: The problem has 76245 linear constraint coefficients.
# NOTE: The problem has 0 nonlinear constraints (0 LE, 0 EQ, 0 GE, 0 range).
# NOTE: The OPTMODEL presolver is disabled for linear problems.
# NOTE: The initial MILP heuristics are applied.
# NOTE: The MILP presolver value AUTOMATIC is applied.
# NOTE: The MILP presolver removed 0 variables and 0 constraints.
# NOTE: The MILP presolver removed 0 constraint coefficients.
# NOTE: The MILP presolver modified 0 constraint coefficients.
# NOTE: The presolved problem has 38220 variables, 390 constraints, and 76245 constraint coefficients.
# NOTE: The MILP solver is called.
# NOTE: The parallel Branch and Cut algorithm is used.
# NOTE: The Branch and Cut algorithm is using up to 16 threads.
#          Node   Active   Sols    BestInteger      BestBound      Gap    Time
#                 0        1      5  55321.0000000              0    55321       0
#                 0        1      5  55321.0000000   6371.5284122  768,25%       0
#                 0        1      5  55321.0000000   9829.6384365  462,80%       1
#                 0        1      7  39030.0000000   9829.6384365  297,06%       1
#                 0        1      7  39030.0000000  11540.6015405  238,20%       1
#                 0        1      7  39030.0000000  12795.4924696  205,03%       1
#                 0        1      7  39030.0000000  13806.2596166  182,70%       2
#                 0        1      7  39030.0000000  14578.5297072  167,72%       2
#                 0        1      7  39030.0000000  15227.4376698  156,31%       3
#                 0        1      7  39030.0000000  15672.4305665  149,04%       3
#                 0        1      7  39030.0000000  15969.3877632  144,41%       4
#                 0        1      7  39030.0000000  16200.6908615  140,92%       5
#                 0        1      7  39030.0000000  16365.4175951  138,49%       5
#                 0        1      7  39030.0000000  16496.9357583  136,59%       6
#                 0        1      7  39030.0000000  16610.1880306  134,98%       6
#                 0        1      7  39030.0000000  16708.4558384  133,59%       7
#                 0        1      7  39030.0000000  16769.2464520  132,75%       7
#                 0        1      7  39030.0000000  16817.3618143  132,08%       8
#                 0        1      7  39030.0000000  16839.6616712  131,77%       8
#                 0        1      7  39030.0000000  16856.0308835  131,55%       9
#                 0        1      7  39030.0000000  16872.8324389  131,32%       9
#                 0        1      7  39030.0000000  16896.8236984  130,99%       9
#                 0        1      7  39030.0000000  16908.4682971  130,83%      10
#                 0        1      7  39030.0000000  16911.2265812  130,79%      10
#                 0        1      7  39030.0000000  16914.0234242  130,76%      10
#                 0        1      7  39030.0000000  16918.5241182  130,69%      10
#                 0        1      9  32166.0000000  16918.5241182   90,12%      10
#                 0        1      9  32166.0000000  16920.7331701   90,10%      11
#                 0        1      9  32166.0000000  16921.3355670   90,09%      11
#                 0        1      9  32166.0000000  16923.6499734   90,07%      11
# NOTE: The MILP solver added 1608 cuts with 3692 cut coefficients at the root.
#                10        7     10  28880.0000000  16924.7380476   70,64%      14
#                16       12     13  19933.0130412  16924.8895483   17,77%      14
#                22       18     13  19933.0130412  16924.8895483   17,77%      15
#                27       18     15  19544.0000000  16924.8895483   15,47%      15
#                54       40     18  18514.0000000  16924.8895483    9,39%      15
#               107       74     19  18472.0000000  16925.4095954    9,14%      16
#               135       97     20  18347.0000000  16926.3500474    8,39%      16
#               170      129     21  17373.0000000  16926.3500474    2,64%      16
#               188       62     23  17218.0037544  16928.5366419    1,71%      17
#               203       51     24  16932.0010404  16928.5366419    0,02%      17
#               213        0     24  16932.0010404  16932.0010404    0,00%      17
# NOTE: Optimal.
# NOTE: Objective = 16932,00104.
# NOTE: The output table 'ASSIGNMENTS' in caslib 'CASUSER(phchri)' has 195 rows and 7 columns.
# NOTE: The output table 'SITES' in caslib 'CASUSER(phchri)' has 11 rows and 5 columns.

# %% [markdown]
# The following code computes the parts of the objective from the output data sets to see how long the total distance between sites and customers is compared to the fixed charge building costs of the sites.

# %%
# Print the sum of the distances
total_distance = assignments["distance"].sum()
print(f"Total distance: {total_distance}")

# Print the sum of the building costs
total_site_cost = sites["cost"].sum()
print(f"Total site cost: {total_site_cost}")

print(f"Objective: {total_distance + total_site_cost}")
# Out:
# Total distance: 11735.0
# Total site cost: 5197.0
# Objective: 16932.0

# %% [markdown]
# Now display the map with the solution.

# %%
map_noregion = folium.Map(location=(52, 9), zoom_start=6)

# Plot all cities
for index, row in indata.iterrows():
    folium.Marker(location=[row["lat"], row["lon"]], tooltip=f'{row["name"]}<br>Size: {row["size"]}<br>Density: {row["density"]}').add_to(map_noregion)

# Plot the cities that are sites to build
for index, row in sites.iterrows():
    folium.Marker(location=[row["lat"], row["lon"]], tooltip=row["name"], icon=folium.Icon(color="green")).add_to(map_noregion)

# Plot the assignments of customers to sites
for idx, row in assignments.iterrows():
    folium.PolyLine([[row["lat1"], row["lon1"]],
                     [row["lat2"], row["lon2"]]]).add_to(map_noregion)

display(map_noregion)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d120edf60b524746fcf57481115d788 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d120edf60b524746fcf57481115d788&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d120edf60b524746fcf57481115d788 = L.map(
#                 &quot;map_4d120edf60b524746fcf57481115d788&quot;,
#                 {
#                     center: [52.0, 9.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_491b996aeaed839d481a532254c4aa46 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_491b996aeaed839d481a532254c4aa46.addTo(map_4d120edf60b524746fcf57481115d788);
#
#
#             var marker_b67c8de88dbee9ed6a796c75ef20cb8d = L.marker(
#                 [52.51767, 13.405538],
#                 {}
#             ).addTo(map_4d120edf60b524746fcf57481115d788);
#
#
#             marker_b67c8de88dbee9ed6a796c75ef20cb8d.bindTooltip(
#                 `&lt;div&gt;
#                      Berlin, Stadt&lt;br&gt;Size: 3755251&lt;br&gt;Density: 4214
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e5d98f1e4d2db42fd1f01040ecd5c071 = L.marker(
#                 [53.550678, 9.99697],
#                 {}
#             ).addTo(map_4d120edf60b524746fcf57481115d788);
#
#
#             marker_e5d98f1e4d2db42fd1f01040ecd5c071.bindTooltip(
#                 `&lt;div&gt;
#                      Hamburg, Freie und Hansestadt&lt;br&gt;Size: 1892122&lt;br&gt;Density: 2506
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ad562b1fd0f3fa389497bc9643fcad64 = L.marker(
#                 [48.137683, 11.575997],
#                 {}
#             ).addTo(map_4d120edf60b524746fcf57481115d788);
#
#
#             marker_ad562b1fd0f3fa389497bc9643fcad64.bindTooltip(
#                 `&lt;div&gt;
#                      München, Landeshauptstadt&lt;br&gt;Size: 1512491&lt;br&gt;Density: 4868
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_72fb65235b53151efcd9718a12f1dbed = L.marker(
#                 [50.938107, 6.957068],
#                 {}
#             ).addTo(map_4d120edf60b524746fcf57481115d788);
#
#
#             marker_72fb65235b53151efcd9718a12f1dbed.bindTooltip(
#                 `&lt;div&gt;
#                      Köln, Stadt&lt;br&gt;Size: 1084831&lt;br&gt;Density: 2678
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3d70b41a2399cf3385cf061955ff0653 = L.marker(
#                 [50.11088, 8.682433],
#                 {}
#             ).addTo(map_4d120edf60b524746fcf57481115d788);
#
#
#             marker_3d70b41a2399cf3385cf061955ff0653.bindTooltip(
#                 `&lt;div&gt;
#                      Frankfurt am Main, Stadt&lt;br&gt;Size: 773068&lt;br&gt;Density: 3113
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e57a678f2bc579314da469337272ff85 = L.marker(
#                 [48.775817, 9.177734],
#                 {}
#             ).addTo(map_4d120edf60b524746fcf57481115d788);
#
#
#             marker_e57a678f2bc579314da469337272ff85.bindTooltip(
#                 `&lt;div&gt;
#                      Stuttgart, Landeshauptstadt&lt;br&gt;Size: 632865&lt;br&gt;Density: 3052
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_36d6b375bd53eff790408f5de2c001ce = L.marker(
#                 [51.22422, 6.780068],
#                 {}
#             ).addTo(map_4d120edf60b524746fcf57481115d788);
#
#
#             marker_36d6b375bd53eff790408f5de2c001ce.bindTooltip(
#                 `&lt;div&gt;
#                      Düsseldorf, Stadt&lt;br&gt;Size: 629047&lt;br&gt;Density: 2893
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fd9e10aebf40acfbd26b65874f9f4da3 = L.marker(
#                 [51.338288, 12.377931],
#                 {}
#             ).addTo(map_4d120edf60b524746fcf57481115d788);
#
#
#             marker_fd9e10aebf40acfbd26b65874f9f4da3.bindTooltip(
#                 `&lt;div&gt;
#                      Leipzig, Stadt&lt;br&gt;Size: 616093&lt;br&gt;Density: 2069
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_272a2e7d806c4672c4d0032e93156f28 = L.marker(
#                 [51.514171, 7.464165],
#                 {}
#             ).addTo(map_4d120edf60b524746fcf57481115d788);
#
#
#             marker_272a2e7d806c4672c4d0032e93156f28.bindTooltip(
#                 `&

# %% [markdown]
# #### Modify the Example to Respect Regions
#
# The following code modifies the OPTMODEL code by restricting the possible assignments to assignments within the region.
#
# We can use BY-Group Processing to solve the problem for each state individually without changing the OPTMODEL code. See https://go.documentation.sas.com/doc/en/pgmsascdc/default/casactmopt/casactmopt_optimization_details05.htm for more details.

# %%
# Using groupby we can solve each state individually. Note that we have to use the name of the variable in the data table.
_ = sas.runOptmodel(optmodel_code, groupby="state")

# Create output data frames to plot the solution
assignments = sas.CASTable("assignments")
sites = sas.CASTable("sites")
# Out:
# NOTE: There were 6 rows read from table 'INDATA' in caslib 'CASUSER(phchri)'.
# NOTE: Problem generation will use 16 threads.
# NOTE: The problem has 42 variables (0 free, 0 fixed).
# NOTE: The problem has 42 binary and 0 integer variables.
# NOTE: The problem has 12 linear constraints (6 LE, 6 EQ, 0 GE, 0 range).
# NOTE: The problem has 78 linear constraint coefficients.
# NOTE: The problem has 0 nonlinear constraints (0 LE, 0 EQ, 0 GE, 0 range).
# NOTE: The OPTMODEL presolver is disabled for linear problems.
# NOTE: The initial MILP heuristics are applied.
# NOTE: The MILP presolver value AUTOMATIC is applied.
# NOTE: The MILP presolver removed 0 variables and 0 constraints.
# NOTE: The MILP presolver removed 0 constraint coefficients.
# NOTE: The MILP presolver modified 6 constraint coefficients.
# NOTE: The presolved problem has 42 variables, 12 constraints, and 78 constraint coefficients.
# NOTE: The MILP solver is called.
# NOTE: The parallel Branch and Cut algorithm is used.
# NOTE: The Branch and Cut algorithm is using up to 16 threads.
#          Node   Active   Sols    BestInteger      BestBound      Gap    Time
#                 0        1      1   1715.0000000   1248.8220037   37,33%       0
# NOTE: The MILP presolver is applied again.
#                 0        1      2   1379.0000000   1273.1223323    8,32%       0
#                 0        1      2   1379.0000000   1273.1223323    8,32%       0
#                 0        1      3   1358.0000000   1358.0000000    0,00%       0
# NOTE: Optimal.
# NOTE: Objective = 1358.
# NOTE: The output table 'ASSIGNMENTS' in caslib 'CASUSER(phchri)' added 6 rows for the current BY group.
# NOTE: The output table 'SITES' in caslib 'CASUSER(phchri)' added 1 rows for the current BY group.
# NOTE: There were 1 rows read from table 'INDATA' in caslib 'CASUSER(phchri)'.
# NOTE: Problem generation will use 16 threads.
# NOTE: The problem has 2 variables (0 free, 0 fixed).
# NOTE: The problem has 2 binary and 0 integer variables.
# NOTE: The problem has 2 linear constraints (1 LE, 1 EQ, 0 GE, 0 range).
# NOTE: The problem has 3 linear constraint coefficients.
# NOTE: The problem has 0 nonlinear constraints (0 LE, 0 EQ, 0 GE, 0 range).
# NOTE: The OPTMODEL presolver is disabled for linear problems.
# NOTE: The initial MILP heuristics are applied.
# NOTE: The MILP presolver value AUTOMATIC is applied.
# NOTE: The MILP presolver removed all variables and constraints.
# NOTE: Optimal.
# NOTE: Objective = 2506.
# NOTE: The output table 'ASSIGNMENTS' in caslib 'CASUSER(phchri)' added 1 rows for the current BY group.
# NOTE: The output table 'SITES' in caslib 'CASUSER(phchri)' added 1 rows for the current BY group.
# NOTE: There were 21 rows read from table 'INDATA' in caslib 'CASUSER(phchri)'.
# NOTE: Problem generation will use 16 threads.
# NOTE: The problem has 462 variables (0 free, 0 fixed).
# NOTE: The problem has 462 binary and 0 integer variables.
# NOTE: The problem has 42 linear constraints (21 LE, 21 EQ, 0 GE, 0 range).
# NOTE: The problem has 903 linear constraint coefficients.
# NOTE: The problem has 0 nonlinear constraints (0 LE, 0 EQ, 0 GE, 0 range).
# NOTE: The OPTMODEL presolver is disabled for linear problems.
# NOTE: The initial MILP heuristics are applied.
# NOTE: The MILP presolver value AUTOMATIC is applied.
# NOTE: The MILP presolver removed 0 variables and 0 constraints.
# NOTE: The MILP presolver removed 0 constraint coefficients.
# NOTE: The MILP presolver modified 21 constraint coefficients.
# NOTE: The presolved problem has 462 variables, 42 constraints, and 903 constraint coefficients.
# NOTE: The MILP solver is called.
# NOTE: The parallel Branch and Cut algorithm is used.
# NOTE: The Branch and Cut algorithm is using up to 16 threads.
#          Node   Active   Sols    BestInteger      BestBound      Gap    Time
#                 0        1      1   2983.0000000    734.3963319  306,18%       0
#                 0        1      1   2983.0000000   1254.6125750  137,76%       0
#                 0        1      1   2983.0000000   1492.2068003   99,91%       0
#                 0        1      1   2983.0000000   1658.6417587   79,85%       0
#                 0        1      1   2983.0000000   1806.2923002   65,14%       0
#                 0        1      2   1831.0000000   1831.0000000    0,00%       0
#                 0        0      2   1831.0000000   1831.0000000    0,00%       0
# NOTE: The MILP solver added 162 cuts with 1575 cut coefficients at the root.
# NOTE: Optimal.
# NOTE: Objective = 1831.
# NOTE: The output table 'ASSIGNMENTS' in caslib 'CASUSER(phchri)' added 21 rows for the current BY group.
# NOTE: The output table 'SITES' in caslib 'CASUSER(phchri)' added 2 rows for the current BY group.
# NOTE: There were 2 rows read from table 'INDATA' in caslib 'CASUSER(phchri)'.
# NOTE: Problem generation will use 16 threads.
# NOTE: The problem has 6 variables (0 free, 0 fixed).
# NOTE: The problem has 6 binary and 0 integer variables.
# NOTE: The problem has 4 linear constraints (2 LE, 2 EQ, 0 GE, 0 range).
# NOTE: The problem has 10 linear constraint coefficients.
# NOTE: The problem has 0 nonlinear constraints (0 LE, 0 EQ, 0 GE, 0 range).
# NOTE: The OPTMODEL presolver is disabled for linear problems.
# NOTE: The initial MILP heuristics are applied.
# NOTE: The MILP presolver value AUTOMATIC is applied.
# NOTE: The MILP presolver removed all variables and constraints.
# NOTE: Optimal.
# NOTE: Objective = 1193.
# NOTE: The output table 'ASSIGNMENTS' in caslib 'CASUSER(phchri)' added 2 rows for the current BY group.
# NOTE: The output table 'SITES' in caslib 'CASUSER(phchri)' added 1 rows for the current BY group.
# NOTE: There were 76 rows read from table 'INDATA' in caslib 'CASUSER(phchri)'.
# NOTE: Problem generation will use 16 threads.
# NOTE: The problem has 5852 variables (0 free, 0 fixed).
# NOTE: The problem has 5852 binary and 0 integer variables.
# NOTE: The problem has 152 linear constraints (76 LE, 76 EQ, 0 GE, 0 range).
# NOTE: The problem has 11628 linear constraint coefficients.
# NOTE: The problem has 0 nonlinear constraints (0 LE, 0 EQ, 0 GE, 0 range).
# NOTE: The OPTMODEL presolver is disabled for linear problems.
# NOTE: The initial MILP heuristics are applied.
# NOTE: The MILP presolver value AUTOMATIC is applied.
# NOTE: The MILP presolver removed 0 variables and 0 constraints.
# NOTE: The MILP presolver removed 0 constraint coefficients.
# NOTE: The MILP presolver modified 0 constraint coefficients.
# NOTE: The presolved problem has 5852 variables, 152 constraints, and 11628 constraint coefficients.
# NOTE: The MILP solver is called.
# NOTE: The parallel Branch and Cut algorithm is used.
# NOTE: The Branch and Cut algorithm is using up to 16 threads.
#          Node   Active   Sols    BestInteger      BestBound      Gap    Time
#                 0        1      5   7054.0000000              0   7054.0       0
#                 0        1      5   7054.0000000   1993.5711534  253,84%       0
#                 0        1      5   7054.0000000   2700.2236088  161,24%       0
#                 0        1      5   7054.0000000   3109.7240946  126,84%       0
#                 0        1      5   7054.0000000   3321.6577066  112,36%       0
#                 0        1      5   7054.0000000   3473.5700656  103,08%       0
#                 0        1      5   7054.0000000   3595.7517478   96,18%       0
#                 0        1      5   7054.0000000   3704.1872979   90,43%       0
#                 0        1      5   7054.0000000   3804.1759986   85,43%       0
#                 0        1      5   7054.0000000   3910.9589510   80,36%       1
#                 0        1      5   7054.0000000   3978.2925504   77,31%       1
#                 0        1      5   7054.0000000   4022.8657825   75,35%       1
#                 0        1      5   7054.0000000   4040.1881282   74,60%       1
#                 0        1      5   7054.0000000   4057.1994122   73,86%       1
#                 0        1      5   7054.0000000   4081.6232633   72,82%       1
#                 0        1      5   7054.0000000   4099.1184820   72,09%       2
#                 0        1      5   7054.0000000   4108.1762537   71,71%       2
#                 0        1      5   7054.0000000   4114.4431334   71,44%       2
#                 0        1      8   5332.0000000   4114.4431334   29,59%       2
#                 0        1      8   5332.0000000   4117.4638194   29,50%       2
#                 0        1      8   5332.0000000   4117.4638194   29,50%       2
# NOTE: The MILP presolver is applied again.
#                 0        1      9   4928.0000000   4117.4638194   19,69%       2
#                 0        1      9   4928.0000000   4117.4638194   19,69%       2
#                 0        1      9   4928.0000000   4117.4638194   19,69%       2
#                 0        1      9   4928.0000000   4117.4638194   19,69%       2
#                 0        1      9   4928.0000000   4117.4638194   19,69%       3
#                 0        1      9   4928.0000000   4117.4638194   19,69%       3
#                 0        1      9   4928.0000000   4117.4638194   19,69%       3
#                 0        1      9   4928.0000000   4117.4638194   19,69%       3
#                 0        1      9   4928.0000000   4117.4638194   19,69%       3
#                 0        1      9   4928.0000000   4117.4638194   19,69%       3
#                 0        1      9   4928.0000000   4117.4638194   19,69%       3
#                 0        1      9   4928.0000000   4117.4638194   19,69%       4
#                 0        1      9   4928.0000000   4117.4638194   19,69%       4
#                 0        1      9   4928.0000000   4117.4638194   19,69%       4
#                 0        1      9   4928.0000000   4117.4638194   19,69%       4
#                 0        1      9   4928.0000000   4117.4638194   19,69%       4
#                 0        1      9   4928.0000000   4117.7221046   19,68%       4
# NOTE: The MILP presolver is applied again.
#                 0        1      9   4928.0000000   4117.7221046   19,68%       4
#                 0        1      9   4928.0000000   4117.7221046   19,68%       4
#                 0        1      9   4928.0000000   4117.7221046   19,68%       4
#                 0        1      9   4928.0000000   4117.7221046   19,68%       5
#                 0        1      9   4928.0000000   4117.7221046   19,68%       5
#                 0        1      9   4928.0000000   4117.7221046   19,68%       5
#                 0        1      9   4928.0000000   4117.7221046   19,68%       5
#                 0        1      9   4928.0000000   4117.7221046   19,68%       5
#                 0        1      9   4928.0000000   4117.7221046   19,68%       5
#                 0        1      9   4928.0000000   4117.7221046   19,68%       5
#                 0        1      9   4928.0000000   4117.7221046   19,68%       5
#                 0        1      9   4928.0000000   4117.7221046   19,68%       6
#                 0        1      9   4928.0000000   4117.7221046   19,68%       6
#                 0        1      9   4928.0000000   4117.7221046   19,68%       6
#                 0        1      9   4928.0000000   4117.7221046   19,68%       6
#                 0        1      9   4928.0000000   4117.7221046   19,68%       6
#                 0        1     11   4563.0000000   4117.7221046   10,81%       6
#                 0        1     11   4563.0000000   4117.7516998   10,81%       6
# NOTE: The MILP presolver is applied again.
#                 0        1     12   4536.0000000   4117.7516998   10,16%       6
#                 0        1     12   4536.0000000   4117.7516998   10,16%       6
#                 0        1     12   4536.0000000   4117.7516998   10,16%       6
#                 0        1     12   4536.0000000   4117.7516998   10,16%       6
#                 0        1     12   4536.0000000   4117.7516998   10,16%       6
#                 0        1     12   4536.0000000   4117.7516998   10,16%       7
#                 0        1     12   4536.0000000   4117.7516998   10,16%       7
#                 0        1     12   4536.0000000   4117.7516998   10,16%       7
#                 0        1     12   4536.0000000   4117.7516998   10,16%       7
#                 0        1     12   4536.0000000   4117.7516998   10,16%       7
#                 0        1     12   4536.0000000   4117.7516998   10,16%       7
#                 0        1     12   4536.0000000   4117.7516998   10,16%       7
#                 0        1     13   4120.0000000   4120.0000000    0,00%       7
# NOTE: The MILP solver added 498 cuts with 5484 cut coefficients at the root.
# NOTE: Optimal.
# NOTE: Objective = 4120.
# NOTE: The output table 'ASSIGNMENTS' in caslib 'CASUSER(phchri)' added 76 rows for the current BY group.
# NOTE: The output table 'SITES' in caslib 'CASUSER(phchri)' added 3 rows for the current BY group.
# NOTE: There were 12 rows read from table 'INDATA' in caslib 'CASUSER(phchri)'.
# NOTE: Problem generation will use 16 threads.
# NOTE: The problem has 156 variables (0 free, 0 fixed).
# NOTE: The problem has 156 binary and 0 integer variables.
# NOTE: The problem has 24 linear constraints (12 LE, 12 EQ, 0 GE, 0 range).
# NOTE: The problem has 300 linear constraint coefficients.
# NOTE: The problem has 0 nonlinear constraints (0 LE, 0 EQ, 0 GE, 0 range).
# NOTE: The OPTMODEL presolver is disabled for linear problems.
# NOTE: The initial MILP heuristics are applied.
# NOTE: The MILP presolver value AUTOMATIC is applied.
# NOTE: The MILP presolver removed 0 variables and 0 constraints.
# NOTE: The MILP presolver removed 0 constraint coefficients.
# NOTE: The MILP presolver modified 12 constraint coefficients.
# NOTE: The presolved problem has 156 variables, 24 constraints, and 300 constraint coefficients.
# NOTE: The MILP solver is called.
# NOTE: The parallel Branch and Cut algorithm is used.
# NOTE: The Branch and Cut algorithm is using up to 16 threads.
#          Node   Active   Sols    BestInteger      BestBound      Gap    Time
#                 0        1      2   1594.0000000              0   1594.0       0
#                 0        1      2   1594.0000000   1034.5150261   54,08%       0
#                 0        1      2   1594.0000000   1054.4434136   51,17%       0
# NOTE: The MILP presolver is applied again.
#                 0        1      3   1348.0000000   1054.4434136   27,84%       0
#                 0        1      3   1348.0000000   1054.4434136   27,84%       0
# NOTE: Optimal.
# NOTE: Objective = 1348.
# NOTE: The output table 'ASSIGNMENTS' in caslib 'CASUSER(phchri)' added 12 rows for the current BY group.
# NOTE: The output table 'SITES' in caslib 'CASUSER(phchri)' added 1 rows for the current BY group.
# NOTE: There were 10 rows read from table 'INDATA' in caslib 'CASUSER(phchri)'.
# NOTE: Problem generation will use 16 threads.
# NOTE: The problem has 110 variables (0 free, 0 fixed).
# NOTE: The problem has 110 binary and 0 integer variables.
# NOTE: The problem has 20 linear constraints (10 LE, 10 EQ, 0 GE, 0 range).
# NOTE: The problem has 210 linear constraint coefficients.
# NOTE: The problem has 0 nonlinear constraints (0 LE, 0 EQ, 0 GE, 0 range).
# NOTE: The OPTMODEL presolver is disabled for linear problems.
# NOTE: The initial MILP heuristics are applied.
# NOTE: The MILP presolver value AUTOMATIC is applied.
# NOTE: The MILP presolver removed 0 variables and 0 constraints.
# NOTE: The MILP presolver removed 0 constraint coefficients.
# NOTE: The MILP presolver modified 10 constraint coefficients.
# NOTE: The presolved problem has 110 variables, 20 constraints, and 210 constraint coefficients.
# NOTE: The MILP solver is called.
# NOTE: The parallel Branch and Cut algorithm is used.
# NOTE: The Branch and Cut algorithm is using up to 16 threads.
#          Node   Active   Sols    BestInteger      BestBound      Gap    Time
#                 0        1      1   1331.0000000    779.6020622   70,73%       0
# NOTE: The MILP presolver is applied again.
#                 0        1      1   1331.0000000    843.2716561   57,84%       0
#                 0        1      2   1071.0000000   1071.0000000    0,00%       0
# NOTE: The MILP solver added 39 cuts with 186 cut coefficients at the root.
# NOTE: Optimal.
# NOTE: Objective = 1071.
# NOTE: The output table 'ASSIGNMENTS' in caslib 'CASUSER(phchri)' added 10 rows for the current BY group.
# NOTE: The output table 'SITES' in caslib 'CASUSER(phchri)' added 1 rows for the current BY group.
# NOTE: There were 26 rows read from table 'INDATA' in caslib 'CASUSER(phchri)'.
# NOTE: Problem generation will use 16 threads.
# NOTE: The problem has 702 variables (0 free, 0 fixed).
# NOTE: The problem has 702 binary and 0 integer variables.
# NOTE: The problem has 52 linear constraints (26 LE, 26 EQ, 0 GE, 0 range).
# NOTE: The problem has 1378 linear constraint coefficients.
# NOTE: The problem has 0 nonlinear constraints (0 LE, 0 EQ, 0 GE, 0 range).
# NOTE: The OPTMODEL presolver is disabled for linear problems.
# NOTE: The initial MILP heuristics are applied.
# NOTE: The MILP presolver value AUTOMATIC is applied.
# NOTE: The MILP presolver removed 0 variables and 0 constraints.
# NOTE: The MILP presolver removed 0 constraint coefficients.
# NOTE: The MILP presolver modified 26 constraint coefficients.
# NOTE: The presolved problem has 702 variables, 52 constraints, and 1378 constraint coefficients.
# NOTE: The MILP solver is called.
# NOTE: The parallel Branch and Cut algorithm is used.
# NOTE: The Branch and Cut algorithm is using up to 16 threads.
#          Node   Active   Sols    BestInteger      BestBound      Gap    Time
#                 0        1      2   2905.0000000              0   2905.0       0
#                 0        1      2   2905.0000000   1026.5182587  183,00%       0
#                 0        1      2   2905.0000000   1463.6978596   98,47%       0
#                 0        1      2   2905.0000000   1805.7236197   60,88%       0
#                 0        1      2   2905.0000000   1805.7236197   60,88%       0
# NOTE: The MILP presolver is applied again.
#                 0        1      2   2905.0000000   1805.7236197   60,88%       0
#                 0        1      2   2905.0000000   1805.7236197   60,88%       0
#                 0        1      2   2905.0000000   1849.9176313   57,03%       0
#                 0        1      2   2905.0000000   1956.6368286   48,47%       0
#                 0        1      2   2905.0000000   2064.4412657   40,72%       0
#                 0        1      2   2905.0000000   2176.3553843   33,48%       0
# NOTE: The MILP presolver is applied again.
#                 0        1      2   2905.0000000   2176.3553843   33,48%       0
#                 0        1      2   2905.0000000   2176.3553843   33,48%       0
#                 0        1      2   2905.0000000   2176.3553843   33,48%       0
#                 0        1      2   2905.0000000   2176.3553843   33,48%       0
#                 0        1      2   2905.0000000   2176.3553843   33,48%       0
#                 0        1      2   2905.0000000   2176.3553843   33,48%       0
#                 0        1      2   2905.0000000   2260.8966340   28,49%       0
#                 0        1      2   2905.0000000   2302.3146955   26,18%       0
#                 0        1      2   2905.0000000   2347.9994116   23,72%       0
#                 0        1      3   2348.0000000   2347.9994116    0,00%       0
# NOTE: The MILP solver added 104 cuts with 507 cut coefficients at the root.
# NOTE: Optimal.
# NOTE: Objective = 2348.
# NOTE: The output table 'ASSIGNMENTS' in caslib 'CASUSER(phchri)' added 26 rows for the current BY group.
# NOTE: The output table 'SITES' in caslib 'CASUSER(phchri)' added 2 rows for the current BY group.
# NOTE: There were 17 rows read from table 'INDATA' in caslib 'CASUSER(phchri)'.
# NOTE: Problem generation will use 16 threads.
# NOTE: The problem has 306 variables (0 free, 0 fixed).
# NOTE: The problem has 306 binary and 0 integer variables.
# NOTE: The problem has 34 linear constraints (17 LE, 17 EQ, 0 GE, 0 range).
# NOTE: The problem has 595 linear constraint coefficients.
# NOTE: The problem has 0 nonlinear constraints (0 LE, 0 EQ, 0 GE, 0 range).
# NOTE: The OPTMODEL presolver is disabled for linear problems.
# NOTE: The initial MILP heuristics are applied.
# NOTE: The MILP presolver value AUTOMATIC is applied.
# NOTE: The MILP presolver removed 0 variables and 0 constraints.
# NOTE: The MILP presolver removed 0 constraint coefficients.
# NOTE: The MILP presolver modified 17 constraint coefficients.
# NOTE: The presolved problem has 306 variables, 34 constraints, and 595 constraint coefficients.
# NOTE: The MILP solver is called.
# NOTE: The parallel Branch and Cut algorithm is used.
# NOTE: The Branch and Cut algorithm is using up to 16 threads.
#          Node   Active   Sols    BestInteger      BestBound      Gap    Time
#                 0        1      1   3887.0000000   1288.5921322  201,65%       0
#                 0        1      1   3887.0000000   2003.4936492   94,01%       0
#                 0        1      1   3887.0000000   2244.5023499   73,18%       0
#                 0        1      1   3887.0000000   2486.9350082   56,30%       0
#                 0        1      1   3887.0000000   2663.5256325   45,93%       0
#                 0        1      1   3887.0000000   2757.3512843   40,97%       0
#                 0        1      1   3887.0000000   2810.9415646   38,28%       0
#                 0        1      1   3887.0000000   2863.8996024   35,72%       0
#                 0        1      4   3500.0000000   2863.8996024   22,21%       0
#                 0        1      5   2886.0000000   2886.0000000    0,00%       0
#                 0        0      5   2886.0000000   2886.0000000    0,00%       0
# NOTE: The MILP solver added 112 cuts with 692 cut coefficients at the root.
# NOTE: Optimal.
# NOTE: Objective = 2886.
# NOTE: The output table 'ASSIGNMENTS' in caslib 'CASUSER(phchri)' added 17 rows for the current BY group.
# NOTE: The output table 'SITES' in caslib 'CASUSER(phchri)' added 1 rows for the current BY group.
# NOTE: There were 1 rows read from table 'INDATA' in caslib 'CASUSER(phchri)'.
# NOTE: Problem generation will use 16 threads.
# NOTE: The problem has 2 variables (0 free, 0 fixed).
# NOTE: The problem has 2 binary and 0 integer variables.
# NOTE: The problem has 2 linear constraints (1 LE, 1 EQ, 0 GE, 0 range).
# NOTE: The problem has 3 linear constraint coefficients.
# NOTE: The problem has 0 nonlinear constraints (0 LE, 0 EQ, 0 GE, 0 range).
# NOTE: The OPTMODEL presolver is disabled for linear problems.
# NOTE: The initial MILP heuristics are applied.
# NOTE: The MILP presolver value AUTOMATIC is applied.
# NOTE: The MILP presolver removed all variables and constraints.
# NOTE: Optimal.
# NOTE: Objective = 1086.
# NOTE: The output table 'ASSIGNMENTS' in caslib 'CASUSER(phchri)' added 1 rows for the current BY group.
# NOTE: The output table 'SITES' in caslib 'CASUSER(phchri)' added 1 rows for the current BY group.
# NOTE: There were 1 rows read from table 'INDATA' in caslib 'CASUSER(phchri)'.
# NOTE: Problem generation will use 16 threads.
# NOTE: The problem has 2 variables (0 free, 0 fixed).
# NOTE: The problem has 2 binary and 0 integer variables.
# NOTE: The problem has 2 linear constraints (1 LE, 1 EQ, 0 GE, 0 range).
# NOTE: The problem has 3 linear constraint coefficients.
# NOTE: The problem has 0 nonlinear constraints (0 LE, 0 EQ, 0 GE, 0 range).
# NOTE: The OPTMODEL presolver is disabled for linear problems.
# NOTE: The initial MILP heuristics are applied.
# NOTE: The MILP presolver value AUTOMATIC is applied.
# NOTE: The MILP presolver removed all variables and constraints.
# NOTE: Optimal.
# NOTE: Objective = 4214.
# NOTE: The output table 'ASSIGNMENTS' in caslib 'CASUSER(phchri)' added 1 rows for the current BY group.
# NOTE: The output table 'SITES' in caslib 'CASUSER(phchri)' added 1 rows for the current BY group.
# NOTE: There were 4 rows read from table 'INDATA' in caslib 'CASUSER(phchri)'.
# NOTE: Problem generation will use 16 threads.
# NOTE: The problem has 20 variables (0 free, 0 fixed).
# NOTE: The problem has 20 binary and 0 integer variables.
# NOTE: The problem has 8 linear constraints (4 LE, 4 EQ, 0 GE, 0 range).
# NOTE: The problem has 36 linear constraint coefficients.
# NOTE: The problem has 0 nonlinear constraints (0 LE, 0 EQ, 0 GE, 0 range).
# NOTE: The OPTMODEL presolver is disabled for linear problems.
# NOTE: The initial MILP heuristics are applied.
# NOTE: The MILP presolver value AUTOMATIC is applied.
# NOTE: The MILP presolver removed 0 variables and 0 constraints.
# NOTE: The MILP presolver removed 0 constraint coefficients.
# NOTE: The MILP presolver modified 4 constraint coefficients.
# NOTE: The presolved problem has 20 variables, 8 constraints, and 36 constraint coefficients.
# NOTE: The MILP solver is called.
# NOTE: The parallel Branch and Cut algorithm is used.
# NOTE: The Branch and Cut algorithm is using up to 16 threads.
#          Node   Active   Sols    BestInteger      BestBound      Gap    Time
#                 0        1      2    630.0000000              0    630.0       0
#                 0        1      2    630.0000000    430.3733529   46,38%       0
#                 0        0      2    630.0000000    630.0000000    0,00%       0
# NOTE: Optimal.
# NOTE: Objective = 630.
# NOTE: The output table 'ASSIGNMENTS' in caslib 'CASUSER(phchri)' added 4 rows for the current BY group.
# NOTE: The output table 'SITES' in caslib 'CASUSER(phchri)' added 1 rows for the current BY group.
# NOTE: There were 5 rows read from table 'INDATA' in caslib 'CASUSER(phchri)'.
# NOTE: Problem generation will use 16 threads.
# NOTE: The problem has 30 variables (0 free, 0 fixed).
# NOTE: The problem has 30 binary and 0 integer variables.
# NOTE: The problem has 10 linear constraints (5 LE, 5 EQ, 0 GE, 0 range).
# NOTE: The problem has 55 linear constraint coefficients.
# NOTE: The problem has 0 nonlinear constraints (0 LE, 0 EQ, 0 GE, 0 range).
# NOTE: The OPTMODEL presolver is disabled for linear problems.
# NOTE: The initial MILP heuristics are applied.
# NOTE: The MILP presolver value AUTOMATIC is applied.
# NOTE: The MILP presolver removed 0 variables and 0 constraints.
# NOTE: The MILP presolver removed 0 constraint coefficients.
# NOTE: The MILP presolver modified 5 constraint coefficients.
# NOTE: The presolved problem has 30 variables, 10 constraints, and 55 constraint coefficients.
# NOTE: The MILP solver is called.
# NOTE: The parallel Branch and Cut algorithm is used.
# NOTE: The Branch and Cut algorithm is using up to 16 threads.
#          Node   Active   Sols    BestInteger      BestBound      Gap    Time
#                 0        1      1   1404.0000000    914.5332361   53,52%       0
#                 0        1      2   1105.0000000   1105.0000000    0,00%       0
#                 0        0      2   1105.0000000   1105.0000000    0,00%       0
# NOTE: The MILP solver added 14 cuts with 55 cut coefficients at the root.
# NOTE: Optimal.
# NOTE: Objective = 1105.
# NOTE: The output table 'ASSIGNMENTS' in caslib 'CASUSER(phchri)' added 5 rows for the current BY group.
# NOTE: The output table 'SITES' in caslib 'CASUSER(phchri)' added 1 rows for the current BY group.
# NOTE: There were 6 rows read from table 'INDATA' in caslib 'CASUSER(phchri)'.
# NOTE: Problem generation will use 16 threads.
# NOTE: The problem has 42 variables (0 free, 0 fixed).
# NOTE: The problem has 42 binary and 0 integer variables.
# NOTE: The problem has 12 linear constraints (6 LE, 6 EQ, 0 GE, 0 range).
# NOTE: The problem has 78 linear constraint coefficients.
# NOTE: The problem has 0 nonlinear constraints (0 LE, 0 EQ, 0 GE, 0 range).
# NOTE: The OPTMODEL presolver is disabled for linear problems.
# NOTE: The initial MILP heuristics are applied.
# NOTE: The MILP presolver value AUTOMATIC is applied.
# NOTE: The MILP presolver removed 0 variables and 0 constraints.
# NOTE: The MILP presolver removed 0 constraint coefficients.
# NOTE: The MILP presolver modified 6 constraint coefficients.
# NOTE: The presolved problem has 42 variables, 12 constraints, and 78 constraint coefficients.
# NOTE: The MILP solver is called.
# NOTE: The parallel Branch and Cut algorithm is used.
# NOTE: The Branch and Cut algorithm is using up to 16 threads.
#          Node   Active   Sols    BestInteger      BestBound      Gap    Time
#                 0        1      1   1265.0000000    942.3663848   34,24%       0
#                 0        0      2   1175.0000000   1175.0000000    0,00%       0
# NOTE: Optimal.
# NOTE: Objective = 1175.
# NOTE: The output table 'ASSIGNMENTS' in caslib 'CASUSER(phchri)' added 6 rows for the current BY group.
# NOTE: The output table 'SITES' in caslib 'CASUSER(phchri)' added 1 rows for the current BY group.
# NOTE: There were 3 rows read from table 'INDATA' in caslib 'CASUSER(phchri)'.
# NOTE: Problem generation will use 16 threads.
# NOTE: The problem has 12 variables (0 free, 0 fixed).
# NOTE: The problem has 12 binary and 0 integer variables.
# NOTE: The problem has 6 linear constraints (3 LE, 3 EQ, 0 GE, 0 range).
# NOTE: The problem has 21 linear constraint coefficients.
# NOTE: The problem has 0 nonlinear constraints (0 LE, 0 EQ, 0 GE, 0 range).
# NOTE: The OPTMODEL presolver is disabled for linear problems.
# NOTE: The initial MILP heuristics are applied.
# NOTE: The MILP presolver value AUTOMATIC is applied.
# NOTE: The MILP presolver removed 0 variables and 0 constraints.
# NOTE: The MILP presolver removed 0 constraint coefficients.
# NOTE: The MILP presolver modified 3 constraint coefficients.
# NOTE: The presolved problem has 12 variables, 6 constraints, and 21 constraint coefficients.
# NOTE: The MILP solver is called.
# NOTE: The parallel Branch and Cut algorithm is used.
# NOTE: The Branch and Cut algorithm is using up to 16 threads.
#          Node   Active   Sols    BestInteger      BestBound      Gap    Time
#                 0        1      2    422.0000000              0    422.0       0
#                 0        1      2    422.0000000    421.0010000    0,24%       0
#                 0        0      2    422.0000000    422.0000000    0,00%       0
# NOTE: Optimal.
# NOTE: Objective = 422.
# NOTE: The output table 'ASSIGNMENTS' in caslib 'CASUSER(phchri)' added 3 rows for the current BY group.
# NOTE: The output table 'SITES' in caslib 'CASUSER(phchri)' added 1 rows for the current BY group.
# NOTE: There were 4 rows read from table 'INDATA' in caslib 'CASUSER(phchri)'.
# NOTE: Problem generation will use 16 threads.
# NOTE: The problem has 20 variables (0 free, 0 fixed).
# NOTE: The problem has 20 binary and 0 integer variables.
# NOTE: The problem has 8 linear constraints (4 LE, 4 EQ, 0 GE, 0 range).
# NOTE: The problem has 36 linear constraint coefficients.
# NOTE: The problem has 0 nonlinear constraints (0 LE, 0 EQ, 0 GE, 0 range).
# NOTE: The OPTMODEL presolver is disabled for linear problems.
# NOTE: The initial MILP heuristics are applied.
# NOTE: The MILP presolver value AUTOMATIC is applied.
# NOTE: The MILP presolver removed 0 variables and 0 constraints.
# NOTE: The MILP presolver removed 0 constraint coefficients.
# NOTE: The MILP presolver modified 4 constraint coefficients.
# NOTE: The presolved problem has 20 variables, 8 constraints, and 36 constraint coefficients.
# NOTE: The MILP solver is called.
# NOTE: The parallel Branch and Cut algorithm is used.
# NOTE: The Branch and Cut algorithm is using up to 16 threads.
#          Node   Active   Sols    BestInteger      BestBound      Gap    Time
#                 0        1      1    871.0000000    746.8997392   16,62%       0
#                 0        0      2    779.0000000    779.0000000    0,00%       0
# NOTE: Optimal.
# NOTE: Objective = 779.
# NOTE: The output table 'ASSIGNMENTS' in caslib 'CASUSER(phchri)' added 4 rows for the current BY group.
# NOTE: The output table 'SITES' in caslib 'CASUSER(phchri)' added 1 rows for the current BY group.

# %% [markdown]
# Print the objective for the modified problem.

# %%
# Print the sum of the distances
total_distance = assignments["distance"].sum()
print(f"Total distance: {total_distance}")

# Print the sum of the building costs
total_site_cost = sites["cost"].sum()
print(f"Total site cost: {total_site_cost}")

print(f"Objective: {total_distance + total_site_cost}")
# Out:
# Total distance: 9970.0
# Total site cost: 18102.0
# Objective: 28072.0

# %% [markdown]
# Display the map for the modified problem where regions are respected. Note that Berlin, Hamburg, and Saarbrücken have to be sites now since they are the only possible sites in their regions. Bremen chooses Bremerhaven as the site in the state of Bremen (which might or might not be a valid decision to make).

# %%
map_region = folium.Map(location=(52, 9), zoom_start=6)

# Plot all cities
for index, row in indata.iterrows():
    folium.Marker(location=[row["lat"], row["lon"]], tooltip=f'{row["name"]}<br>Size: {row["size"]}<br>Density: {row["density"]}').add_to(map_region)

# Plot the cities that are sites to build
for index, row in sites.iterrows():
    folium.Marker(location=[row["lat"], row["lon"]], tooltip=row["name"], icon=folium.Icon(color="green")).add_to(map_region)

# Plot the assignments of customers to sites
for idx, row in assignments.iterrows():
    folium.PolyLine([[row["lat1"], row["lon1"]],
                     [row["lat2"], row["lon2"]]]).add_to(map_region)

map_region
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af4e669507bd1a90cabbc18e3403473e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af4e669507bd1a90cabbc18e3403473e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af4e669507bd1a90cabbc18e3403473e = L.map(
#                 &quot;map_af4e669507bd1a90cabbc18e3403473e&quot;,
#                 {
#                     center: [52.0, 9.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1bf181079ea70dfd208304b211eda46b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1bf181079ea70dfd208304b211eda46b.addTo(map_af4e669507bd1a90cabbc18e3403473e);
#
#
#             var marker_467f60c95a0854995e4e377ab4159500 = L.marker(
#                 [52.51767, 13.405538],
#                 {}
#             ).addTo(map_af4e669507bd1a90cabbc18e3403473e);
#
#
#             marker_467f60c95a0854995e4e377ab4159500.bindTooltip(
#                 `&lt;div&gt;
#                      Berlin, Stadt&lt;br&gt;Size: 3755251&lt;br&gt;Density: 4214
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8a1660b18f2f04dee70d8e83e9013fe0 = L.marker(
#                 [53.550678, 9.99697],
#                 {}
#             ).addTo(map_af4e669507bd1a90cabbc18e3403473e);
#
#
#             marker_8a1660b18f2f04dee70d8e83e9013fe0.bindTooltip(
#                 `&lt;div&gt;
#                      Hamburg, Freie und Hansestadt&lt;br&gt;Size: 1892122&lt;br&gt;Density: 2506
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_72f3ede9da61051e0f86c77fcb61b1ad = L.marker(
#                 [48.137683, 11.575997],
#                 {}
#             ).addTo(map_af4e669507bd1a90cabbc18e3403473e);
#
#
#             marker_72f3ede9da61051e0f86c77fcb61b1ad.bindTooltip(
#                 `&lt;div&gt;
#                      München, Landeshauptstadt&lt;br&gt;Size: 1512491&lt;br&gt;Density: 4868
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a097afbc034ed281e17c3aff1abde41d = L.marker(
#                 [50.938107, 6.957068],
#                 {}
#             ).addTo(map_af4e669507bd1a90cabbc18e3403473e);
#
#
#             marker_a097afbc034ed281e17c3aff1abde41d.bindTooltip(
#                 `&lt;div&gt;
#                      Köln, Stadt&lt;br&gt;Size: 1084831&lt;br&gt;Density: 2678
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_193d1725e9ba12ef6a7dda9c44464265 = L.marker(
#                 [50.11088, 8.682433],
#                 {}
#             ).addTo(map_af4e669507bd1a90cabbc18e3403473e);
#
#
#             marker_193d1725e9ba12ef6a7dda9c44464265.bindTooltip(
#                 `&lt;div&gt;
#                      Frankfurt am Main, Stadt&lt;br&gt;Size: 773068&lt;br&gt;Density: 3113
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a3468c9ec7a857ab5cd2e7096c3d97a2 = L.marker(
#                 [48.775817, 9.177734],
#                 {}
#             ).addTo(map_af4e669507bd1a90cabbc18e3403473e);
#
#
#             marker_a3468c9ec7a857ab5cd2e7096c3d97a2.bindTooltip(
#                 `&lt;div&gt;
#                      Stuttgart, Landeshauptstadt&lt;br&gt;Size: 632865&lt;br&gt;Density: 3052
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_faa05734018ad9e299d9977a858c48e6 = L.marker(
#                 [51.22422, 6.780068],
#                 {}
#             ).addTo(map_af4e669507bd1a90cabbc18e3403473e);
#
#
#             marker_faa05734018ad9e299d9977a858c48e6.bindTooltip(
#                 `&lt;div&gt;
#                      Düsseldorf, Stadt&lt;br&gt;Size: 629047&lt;br&gt;Density: 2893
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5021d6087c26b9f6757284f9332a5698 = L.marker(
#                 [51.338288, 12.377931],
#                 {}
#             ).addTo(map_af4e669507bd1a90cabbc18e3403473e);
#
#
#             marker_5021d6087c26b9f6757284f9332a5698.bindTooltip(
#                 `&lt;div&gt;
#                      Leipzig, Stadt&lt;br&gt;Size: 616093&lt;br&gt;Density: 2069
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c6da7a509a4df6ea9b3cb17e8be840ee = L.marker(
#                 [51.514171, 7.464165],
#                 {}
#             ).addTo(map_af4e669507bd1a90cabbc18e3403473e);
#
#
#             marker_c6da7a509a4df6ea9b3cb17e8be840ee.bindTooltip(
#                 `&

# %%
# Close the connection to swat
sas.close()
