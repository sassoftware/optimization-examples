# %% [markdown]
# # Facility Location with Regions
#
# Based on Example 14.3 from the SAS Optimization documentation: https://go.documentation.sas.com/doc/en/pgmsascdc/default/casmopt/casmopt_milpsolver_examples03.htm
#
# For a set of customers and sites, choose which sites to build such that:
# - We minimize the sum of the distances between customers and their assigned sites and the building costs of sites
# - The capacity for each site is not exceeded
# - Sites and customers are in same region

# %% [markdown]
# #### Mixed Integer Linear Programming Formulation
#
# $ \begin{array}{llllll}
# \min & \displaystyle \sum _{i \in L} \displaystyle \sum _{j \in F} c_{ij} x_{ij} &+& \displaystyle \sum _{j \in F} f_ j y_ j \\
# \text{s.t.} & \displaystyle \sum _{j \in F} x_{ij} & = & 1 & \forall i \in L & \text{(assign\_def)} \\
# & \displaystyle \sum _{i \in L} d_ i x_{ij} & \leq & Cy_ j & \forall j \in F & \text{(capacity)} \\
# & x_{ij} & = & 0 & \forall i,j \text{ if } r_i \ne r_j & \text{(region\_con)} \\
# \\
# & x_{ij} \in \{ 0,1\} & & & \forall i \in L, j \in F \\
# & y_{j} \in \{ 0,1\} & & & \forall j \in F
# \end{array}
# $

# %% [markdown]
# #### Input Data
#
# For the input data we have a comma-separated value (CSV) file with all cities in Germany with more than 50,000 inhabitants retrieved from the German Federal Office of Statistics (www.destatis.de) that also includes geo locations of the cities for plotting. The following code reads the file and plots the data on a map.

# %%
import folium
import pandas as pd

# Read the input data and make sure the numbers are all parsed correctly, then print the top of the DataFrame
indata = pd.read_csv('cities_germany.csv', sep=';', decimal=',')
indata["size"] = pd.to_numeric(indata["size"].str.replace(" ", ""), errors='coerce')
indata["density"] = pd.to_numeric(indata["density"].str.replace(" ", ""), errors='coerce')
print(indata)

# Display the cities on a map of Germany
map_input = folium.Map(location=(52, 9), zoom_start=6)
for index, row in indata.iterrows():
    folium.Marker(location=[row["lat"], row["lon"]], tooltip=f'{row["name"]}<br>Size: {row["size"]}<br>Density: {row["density"]}').add_to(map_input)
    
map_input
# Out:
#      state                            name     size  density  zipcode  \
# 0       11                   Berlin, Stadt  3755251     4214    10178
# 1        2   Hamburg, Freie und Hansestadt  1892122     2506    20095
# 2        9       München, Landeshauptstadt  1512491     4868    80331
# 3        5                     Köln, Stadt  1084831     2678    50667
# 4        6        Frankfurt am Main, Stadt   773068     3113    60311
# ..     ...                             ...      ...      ...      ...
# 190      1                 Elmshorn, Stadt    50772     2377    25335
# 191      3                    Emden, Stadt    50535      450    26721
# 192      3                   Goslar, Stadt    50203      306    38640
# 193      5                  Willich, Stadt    50144      740    47877
# 194      8  Heidenheim an der Brenz, Stadt    50025      467    89522
#
#            lon        lat  type
# 0    13.405538  52.517670     1
# 1     9.996970  53.550678     1
# 2    11.575997  48.137683     1
# 3     6.957068  50.938107     1
# 4     8.682433  50.110880     1
# ..         ...        ...   ...
# 190   9.655259  53.754958     2
# 191   7.205946  53.370558     2
# 192  10.429312  51.906508     2
# 193   6.550043  51.262542     2
# 194  10.154639  48.677736     2
#
# [195 rows x 8 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7389c7cdd0eabb7cc735ec64ea4982a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7389c7cdd0eabb7cc735ec64ea4982a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7389c7cdd0eabb7cc735ec64ea4982a6 = L.map(
#                 &quot;map_7389c7cdd0eabb7cc735ec64ea4982a6&quot;,
#                 {
#                     center: [52.0, 9.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c042ca702d1884eebfe4376e429d1208 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c042ca702d1884eebfe4376e429d1208.addTo(map_7389c7cdd0eabb7cc735ec64ea4982a6);
#
#
#             var marker_094507bfcda33ebf2323150f59015faf = L.marker(
#                 [52.51767, 13.405538],
#                 {}
#             ).addTo(map_7389c7cdd0eabb7cc735ec64ea4982a6);
#
#
#             marker_094507bfcda33ebf2323150f59015faf.bindTooltip(
#                 `&lt;div&gt;
#                      Berlin, Stadt&lt;br&gt;Size: 3755251&lt;br&gt;Density: 4214
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_747068e7edbfa24640e83a1c5cf2fd31 = L.marker(
#                 [53.550678, 9.99697],
#                 {}
#             ).addTo(map_7389c7cdd0eabb7cc735ec64ea4982a6);
#
#
#             marker_747068e7edbfa24640e83a1c5cf2fd31.bindTooltip(
#                 `&lt;div&gt;
#                      Hamburg, Freie und Hansestadt&lt;br&gt;Size: 1892122&lt;br&gt;Density: 2506
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5746efe7a03fa3dc6474669daba4d292 = L.marker(
#                 [48.137683, 11.575997],
#                 {}
#             ).addTo(map_7389c7cdd0eabb7cc735ec64ea4982a6);
#
#
#             marker_5746efe7a03fa3dc6474669daba4d292.bindTooltip(
#                 `&lt;div&gt;
#                      München, Landeshauptstadt&lt;br&gt;Size: 1512491&lt;br&gt;Density: 4868
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_aeb0ae024b08d66eeee682ba804039a5 = L.marker(
#                 [50.938107, 6.957068],
#                 {}
#             ).addTo(map_7389c7cdd0eabb7cc735ec64ea4982a6);
#
#
#             marker_aeb0ae024b08d66eeee682ba804039a5.bindTooltip(
#                 `&lt;div&gt;
#                      Köln, Stadt&lt;br&gt;Size: 1084831&lt;br&gt;Density: 2678
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_49bc00802a101c580df50fcbe5481030 = L.marker(
#                 [50.11088, 8.682433],
#                 {}
#             ).addTo(map_7389c7cdd0eabb7cc735ec64ea4982a6);
#
#
#             marker_49bc00802a101c580df50fcbe5481030.bindTooltip(
#                 `&lt;div&gt;
#                      Frankfurt am Main, Stadt&lt;br&gt;Size: 773068&lt;br&gt;Density: 3113
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_abafb88fcaac5b689d7f35f9f939e59b = L.marker(
#                 [48.775817, 9.177734],
#                 {}
#             ).addTo(map_7389c7cdd0eabb7cc735ec64ea4982a6);
#
#
#             marker_abafb88fcaac5b689d7f35f9f939e59b.bindTooltip(
#                 `&lt;div&gt;
#                      Stuttgart, Landeshauptstadt&lt;br&gt;Size: 632865&lt;br&gt;Density: 3052
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_703cfe56fe1e1673f29160affc390542 = L.marker(
#                 [51.22422, 6.780068],
#                 {}
#             ).addTo(map_7389c7cdd0eabb7cc735ec64ea4982a6);
#
#
#             marker_703cfe56fe1e1673f29160affc390542.bindTooltip(
#                 `&lt;div&gt;
#                      Düsseldorf, Stadt&lt;br&gt;Size: 629047&lt;br&gt;Density: 2893
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_03e4a155fa439f990645aac814bed345 = L.marker(
#                 [51.338288, 12.377931],
#                 {}
#             ).addTo(map_7389c7cdd0eabb7cc735ec64ea4982a6);
#
#
#             marker_03e4a155fa439f990645aac814bed345.bindTooltip(
#                 `&lt;div&gt;
#                      Leipzig, Stadt&lt;br&gt;Size: 616093&lt;br&gt;Density: 2069
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_28ac200159f98dff2b5020eb0da43568 = L.marker(
#                 [51.514171, 7.464165],
#                 {}
#             ).addTo(map_7389c7cdd0eabb7cc735ec64ea4982a6);
#
#
#             marker_28ac200159f98dff2b5020eb0da43568.bindTooltip(
#                 `&

# %% [markdown]
# #### Defining the Optimization Problem with sasoptpy
#
# In this specific example, every customer location (city) can also be a site. The demand of each city is its size while we use the density as the cost to build a site. This means that building a site in a less densely populated cities is preferable. This leads to an interesting optimization problem for demonstration purposes but has no real-world meaning.
#
# The code below defines the optimization problem and connects it with the data.

# %%
import sasoptpy as so
from geopy.distance import geodesic

C = 5000000

SITES = indata.index.tolist()

lat = indata["lat"]
lon = indata["lon"]
demand = indata["size"]
cost = indata["density"]
region = indata["state"]

PAIRS = [(i, j) for i in SITES for j in SITES]
dist = pd.DataFrame(
    [
        [i, j, round(geodesic((lat[i], lon[i]),(lat[j], lon[j])).km)]
        for (i, j) in PAIRS
    ],
    columns=["i", "j", "dist"],
).set_index(["i", "j"])["dist"]

model = so.Model(name="location")

Assign = model.add_variables(PAIRS, vartype=so.BIN, name="Assign")
Build = model.add_variables(SITES, vartype=so.BIN, name="Build")

_ = model.set_objective(
    so.expr_sum(dist[i, j] * Assign[i, j] for (i, j) in PAIRS)
    + so.expr_sum(cost[j] * Build[j] for j in SITES),
    name="total_cost",
)

_ = model.add_constraints(
    (
        (so.expr_sum(Assign[i, j] for (i, j) in PAIRS if i == t) == 1)
        for t in SITES
    ),
    name="assign_def",
)

_ = model.add_constraints(
    (
        so.expr_sum(demand[i] * Assign[i, j] for (i, j) in PAIRS if j == t)
        <= C * Build[t]
        for t in SITES
    ),
    name="capacity",
)
# Out:
# NOTE: Initialized model location.

# %% [markdown]
# Solve the problem using the SAS solver.

# %%
import swat
from cas import cas_options

cas = swat.CAS(**cas_options)
model.set_session(cas)
_ = model.solve()
# Out:
# NOTE: Added action set 'optimization'.
# NOTE: Converting model location to OPTMODEL.
# NOTE: Submitting OPTMODEL code to CAS server.
# NOTE: Problem generation will use 16 threads.
# NOTE: The problem has 38220 variables (0 free, 0 fixed).
# NOTE: The problem has 38220 binary and 0 integer variables.
# NOTE: The problem has 390 linear constraints (195 LE, 195 EQ, 0 GE, 0 range).
# NOTE: The problem has 76245 linear constraint coefficients.
# NOTE: The problem has 0 nonlinear constraints (0 LE, 0 EQ, 0 GE, 0 range).
# NOTE: The OPTMODEL presolver is disabled for linear problems.
# NOTE: The initial MILP heuristics are applied.
# NOTE: The MILP presolver value AUTOMATIC is applied.
# NOTE: The MILP presolver removed 0 variables and 0 constraints.
# NOTE: The MILP presolver removed 0 constraint coefficients.
# NOTE: The MILP presolver modified 0 constraint coefficients.
# NOTE: The presolved problem has 38220 variables, 390 constraints, and 76245 constraint coefficients.
# NOTE: The MILP solver is called.
# NOTE: The parallel Branch and Cut algorithm is used.
# NOTE: The Branch and Cut algorithm is using up to 16 threads.
#          Node   Active   Sols    BestInteger      BestBound      Gap    Time
#                 0        1      5  63428.0000000              0    63428       0
#                 0        1      5  63428.0000000   6371.5284122  895,49%       0
#                 0        1      5  63428.0000000  10019.4204135  533,05%       1
#                 0        1      6  37644.0000000  10019.4204135  275,71%       1
#                 0        1      6  37644.0000000  11706.0796674  221,58%       1
#                 0        1      6  37644.0000000  12867.7136987  192,55%       1
#                 0        1      6  37644.0000000  13857.4441269  171,65%       2
#                 0        1      6  37644.0000000  14669.9633864  156,61%       2
#                 0        1      6  37644.0000000  15230.0081626  147,17%       3
#                 0        1      6  37644.0000000  15702.6686098  139,73%       3
#                 0        1      6  37644.0000000  15920.0751432  136,46%       4
#                 0        1      6  37644.0000000  16209.4503244  132,23%       5
#                 0        1      6  37644.0000000  16373.6690622  129,91%       5
#                 0        1      6  37644.0000000  16500.9150055  128,13%       6
#                 0        1      6  37644.0000000  16584.3672447  126,98%       6
#                 0        1      6  37644.0000000  16664.0048925  125,90%       7
#                 0        1      6  37644.0000000  16731.2047056  124,99%       7
#                 0        1      6  37644.0000000  16788.0158271  124,23%       8
#                 0        1      6  37644.0000000  16827.9869057  123,70%       8
#                 0        1      6  37644.0000000  16858.2471808  123,30%       9
#                 0        1      6  37644.0000000  16879.4529680  123,02%       9
#                 0        1      6  37644.0000000  16898.3266501  122,77%      10
#                 0        1      6  37644.0000000  16908.6941154  122,63%      10
#                 0        1      6  37644.0000000  16913.0975790  122,57%      10
#                 0        1      6  37644.0000000  16916.6317425  122,53%      11
#                 0        1      6  37644.0000000  16920.6624291  122,47%      11
#                 0        1      8  19304.0000000  16920.6624291   14,09%      11
#                 0        1      8  19304.0000000  16921.4056280   14,08%      11
#                 0        1      8  19304.0000000  16922.3385713   14,07%      11
#                 0        1      8  19304.0000000  16925.3031824   14,05%      12
# NOTE: The MILP solver added 1610 cuts with 3673 cut coefficients at the root.
#                13       10      8  19304.0000000  16925.8500189   14,05%      15
#                31       25      9  19202.0000000  16925.8500189   13,45%      16
#                46       27     10  18988.0000000  16926.2728272   12,18%      16
#                95       53     11  16932.0000000  16928.5383115    0,02%      18
#               109        0     11  16932.0000000  16932.0000000    0,00%      18
# NOTE: Optimal.
# NOTE: Objective = 16932.
# NOTE: The output table 'SOLUTION' in caslib 'CASUSER(phchri)' has 38220 rows and 6 columns.
# NOTE: The output table 'DUAL' in caslib 'CASUSER(phchri)' has 390 rows and 4 columns.
# NOTE: The CAS table 'problemSummary' in caslib 'CASUSER(phchri)' has 20 rows and 4 columns.
# NOTE: The CAS table 'solutionSummary' in caslib 'CASUSER(phchri)' has 18 rows and 4 columns.

# %% [markdown]
# The following code computes the parts of the objective from the output data sets to see how long the total distance between sites and customers is compared to the building costs of the sites.

# %%
assignments = pd.DataFrame([(lat[i], lon[i], lat[j], lon[j], dist[i,j]) 
                            for (i,j) in PAIRS if Assign[i,j].get_value() > 0.5],
                            columns=["lat1", "lon1", "lat2", "lon2","distance" ]
                            )

sites = pd.DataFrame([(indata["name"][j], lat[j], lon[j], cost[j]) 
                      for j in SITES if Build[j].get_value() > 0.5],
                      columns=["name", "lat", "lon","cost" ]
                    )

# Print the sum of the distances
total_distance = assignments["distance"].sum()
print(f"Total distance: {total_distance}")

## Print the sum of the building costs
total_site_cost = sites["cost"].sum()
print(f"Total site cost: {total_site_cost}")

print(f"Objective: {total_distance + total_site_cost}")
# Out:
# Total distance: 11735
# Total site cost: 5197
# Objective: 16932

# %% [markdown]
# Now display the map with the solution.

# %%
map_noregion = folium.Map(location=(52, 9), zoom_start=6)

# Plot all cities
for index, row in indata.iterrows():
    folium.Marker(location=[row["lat"], row["lon"]], tooltip=f'{row["name"]}<br>Size: {row["size"]}<br>Density: {row["density"]}').add_to(map_noregion)

# Plot the cities that are sites to build
for index, row in sites.iterrows():
    folium.Marker(location=[row["lat"], row["lon"]], tooltip=row["name"], icon=folium.Icon(color="green")).add_to(map_noregion)

# Plot the assignments of customers to sites
for idx, row in assignments.iterrows():
    folium.PolyLine([[row["lat1"], row["lon1"]],
                     [row["lat2"], row["lon2"]]]).add_to(map_noregion)

map_noregion
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0ccc1fded13f42cdd952de6914bd2c13 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0ccc1fded13f42cdd952de6914bd2c13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0ccc1fded13f42cdd952de6914bd2c13 = L.map(
#                 &quot;map_0ccc1fded13f42cdd952de6914bd2c13&quot;,
#                 {
#                     center: [52.0, 9.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_94e2e947a085bd1deb47a8b61de2ddf0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_94e2e947a085bd1deb47a8b61de2ddf0.addTo(map_0ccc1fded13f42cdd952de6914bd2c13);
#
#
#             var marker_45b1fffdc508dc1c70b52210679f50f5 = L.marker(
#                 [52.51767, 13.405538],
#                 {}
#             ).addTo(map_0ccc1fded13f42cdd952de6914bd2c13);
#
#
#             marker_45b1fffdc508dc1c70b52210679f50f5.bindTooltip(
#                 `&lt;div&gt;
#                      Berlin, Stadt&lt;br&gt;Size: 3755251&lt;br&gt;Density: 4214
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_32bd4158b28ff2ad8103cf71b5e41ae1 = L.marker(
#                 [53.550678, 9.99697],
#                 {}
#             ).addTo(map_0ccc1fded13f42cdd952de6914bd2c13);
#
#
#             marker_32bd4158b28ff2ad8103cf71b5e41ae1.bindTooltip(
#                 `&lt;div&gt;
#                      Hamburg, Freie und Hansestadt&lt;br&gt;Size: 1892122&lt;br&gt;Density: 2506
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fefff4730a4784f17d95a106c1ac214e = L.marker(
#                 [48.137683, 11.575997],
#                 {}
#             ).addTo(map_0ccc1fded13f42cdd952de6914bd2c13);
#
#
#             marker_fefff4730a4784f17d95a106c1ac214e.bindTooltip(
#                 `&lt;div&gt;
#                      München, Landeshauptstadt&lt;br&gt;Size: 1512491&lt;br&gt;Density: 4868
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_564a40f18d4eaffbd60af563e7c3dfaf = L.marker(
#                 [50.938107, 6.957068],
#                 {}
#             ).addTo(map_0ccc1fded13f42cdd952de6914bd2c13);
#
#
#             marker_564a40f18d4eaffbd60af563e7c3dfaf.bindTooltip(
#                 `&lt;div&gt;
#                      Köln, Stadt&lt;br&gt;Size: 1084831&lt;br&gt;Density: 2678
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f83e7a86d0c8809fb3b20f9105388b72 = L.marker(
#                 [50.11088, 8.682433],
#                 {}
#             ).addTo(map_0ccc1fded13f42cdd952de6914bd2c13);
#
#
#             marker_f83e7a86d0c8809fb3b20f9105388b72.bindTooltip(
#                 `&lt;div&gt;
#                      Frankfurt am Main, Stadt&lt;br&gt;Size: 773068&lt;br&gt;Density: 3113
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e036d3bdb18cd4c8cd958bbfad7aa7b4 = L.marker(
#                 [48.775817, 9.177734],
#                 {}
#             ).addTo(map_0ccc1fded13f42cdd952de6914bd2c13);
#
#
#             marker_e036d3bdb18cd4c8cd958bbfad7aa7b4.bindTooltip(
#                 `&lt;div&gt;
#                      Stuttgart, Landeshauptstadt&lt;br&gt;Size: 632865&lt;br&gt;Density: 3052
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_273d794074e50eafa7a3facc1bbdc104 = L.marker(
#                 [51.22422, 6.780068],
#                 {}
#             ).addTo(map_0ccc1fded13f42cdd952de6914bd2c13);
#
#
#             marker_273d794074e50eafa7a3facc1bbdc104.bindTooltip(
#                 `&lt;div&gt;
#                      Düsseldorf, Stadt&lt;br&gt;Size: 629047&lt;br&gt;Density: 2893
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0b35644d9836ec2cc746a3803565dc0e = L.marker(
#                 [51.338288, 12.377931],
#                 {}
#             ).addTo(map_0ccc1fded13f42cdd952de6914bd2c13);
#
#
#             marker_0b35644d9836ec2cc746a3803565dc0e.bindTooltip(
#                 `&lt;div&gt;
#                      Leipzig, Stadt&lt;br&gt;Size: 616093&lt;br&gt;Density: 2069
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_dd824df6c6e19aa852f35a9bbce3c79e = L.marker(
#                 [51.514171, 7.464165],
#                 {}
#             ).addTo(map_0ccc1fded13f42cdd952de6914bd2c13);
#
#
#             marker_dd824df6c6e19aa852f35a9bbce3c79e.bindTooltip(
#                 `&

# %% [markdown]
# #### Modify the Example to Respect Regions
#
# The following code we redefine the `PAIRS` set and those parts of the model that rely on it to only allow assignments within regions.
#
# Note that by doing this we actually create 16 independent optimization problems, one for each state (some of which are trivial because there is only one choice). The result is an optimization problem with disjoint blocks. By default, the MILP solver detects this structure and deals with it (works better on newer versions). But it's also possible to use this option statement: `options={"with": "milp", "decomp": {"method": "concomp"}}` With these options, the DECOMP algorithm is used that will solve each block independently and in parallel.
#
# The `with` option chooses the solver to use. Depending on its value, it accepts the same options as the `solveLp` action or the `solveMilp` action. The documentation for these can be found here: https://go.documentation.sas.com/doc/en/pgmsascdc/default/casactmopt/casactmopt_optimization_toc.htm

# %%
PAIRS = [(i, j) for i in SITES for j in SITES if region[i] == region[j]]

model = so.Model(name="location_region")

Assign = model.add_variables(PAIRS, vartype=so.BIN, name="Assign")
Build = model.add_variables(SITES, vartype=so.BIN, name="Build")

_ = model.set_objective(
    so.expr_sum(dist[i, j] * Assign[i, j] for (i, j) in PAIRS)
    + so.expr_sum(cost[j] * Build[j] for j in SITES),
    name="total_cost",
)

_ = model.add_constraints(
    (
        (so.expr_sum(Assign[i, j] for (i, j) in PAIRS if i == t) == 1)
        for t in SITES
    ),
    name="assign_def",
)

_ = model.add_constraints(
    (
        so.expr_sum(demand[i] * Assign[i, j] for (i, j) in PAIRS if j == t)
        <= C * Build[t]
        for t in SITES
    ),
    name="capacity",
)

# Solve the problem
cas = swat.CAS(**cas_options)
model.set_session(cas)
_ = model.solve(options={"with": "milp", "decomp": {"method": "concomp"}})
# Out:
# NOTE: Initialized model location_region.
# NOTE: Added action set 'optimization'.
# NOTE: Converting model location_region to DataFrame.
# NOTE: Uploading the problem DataFrame to the server.
# NOTE: Cloud Analytic Services made the uploaded file available as table TMP6OBSG52C in caslib CASUSER(phchri).
# NOTE: The table TMP6OBSG52C has been created in caslib CASUSER(phchri) from binary data uploaded to Cloud Analytic Services.
# NOTE: The problem location_region has 7766 variables (7766 binary, 0 integer, 0 free, 0 fixed).
# NOTE: The problem has 390 constraints (195 LE, 195 EQ, 0 GE, 0 range).
# NOTE: The problem has 15337 constraint coefficients.
# NOTE: The initial MILP heuristics are applied.
# NOTE: The MILP presolver value AUTOMATIC is applied.
# NOTE: The MILP presolver removed 8 variables and 8 constraints.
# NOTE: The MILP presolver removed 13 constraint coefficients.
# NOTE: The MILP presolver modified 116 constraint coefficients.
# NOTE: The presolved problem has 7758 variables, 382 constraints, and 15324 constraint coefficients.
# NOTE: The MILP solver is called.
# NOTE: The Decomposition algorithm is used.
# NOTE: The Decomposition algorithm is executing in the distributed computing environment in single-machine mode.
# NOTE: The DECOMP method value CONCOMP is applied.
# NOTE: The decomposition identification used 0,00 (cpu: 0,00) seconds.
# NOTE: The number of block threads has been reduced to 13 threads.
# NOTE: The problem has a decomposable structure with 13 blocks. The largest block covers 39,79% of the constraints in the problem.
# NOTE: The decomposition subproblems cover 7758 (100%) variables and 382 (100%) constraints.
# NOTE: The deterministic parallel mode is enabled.
# NOTE: The Decomposition algorithm is using up to 16 threads.
#          Iter         Best       Master         Best       LP       IP  CPU Real
#                      Bound    Objective      Integer      Gap      Gap Time Time
#             1   28072.0000   28072.0000   28072.0000    0.00%    0.00%    4    4
#             Node  Active   Sols         Best         Best      Gap    CPU   Real
#                                      Integer        Bound            Time   Time
#                0       1      7   28072.0000   28072.0000    0.00%      4      4
# NOTE: The Decomposition algorithm used 16 threads.
# NOTE: The Decomposition algorithm time is 4,27 seconds.
# NOTE: Optimal.
# NOTE: Objective = 28072.

# %% [markdown]
# Print the objective for the modified problem.

# %%
assignments = pd.DataFrame([(lat[i], lon[i], lat[j], lon[j], dist[i,j]) 
                            for (i,j) in PAIRS if Assign[i,j].get_value() > 0.5],
                            columns=["lat1", "lon1", "lat2", "lon2","distance" ]
                            )

sites = pd.DataFrame([(indata["name"][j], lat[j], lon[j], cost[j]) 
                      for j in SITES if Build[j].get_value() > 0.5],
                      columns=["name", "lat", "lon","cost" ]
                    )

# Print the sum of the distances
total_distance = assignments["distance"].sum()
print(f"Total distance: {total_distance}")

## Print the sum of the building costs
total_site_cost = sites["cost"].sum()
print(f"Total site cost: {total_site_cost}")

print(f"Objective: {total_distance + total_site_cost}")
# Out:
# Total distance: 9970
# Total site cost: 18102
# Objective: 28072

# %% [markdown]
# Display the map for the modified problem where regions are respected. Note that Berlin, Hamburg, and Saarbrücken have to be sites now since they are the only possible sites in their regions. Bremen chooses Bremerhaven as the site in the state of Bremen (which might or might not be a valid decision to make).

# %%
map_region = folium.Map(location=(52, 9), zoom_start=6)

# Plot all cities
for index, row in indata.iterrows():
    folium.Marker(location=[row["lat"], row["lon"]], tooltip=f'{row["name"]}<br>Size: {row["size"]}<br>Density: {row["density"]}').add_to(map_region)

# Plot the cities that are sites to build
for index, row in sites.iterrows():
    folium.Marker(location=[row["lat"], row["lon"]], tooltip=row["name"], icon=folium.Icon(color="green")).add_to(map_region)

# Plot the assignments of customers to sites
for idx, row in assignments.iterrows():
    folium.PolyLine([[row["lat1"], row["lon1"]],
                     [row["lat2"], row["lon2"]]]).add_to(map_region)

map_region
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4c1c190afe9d7252c592107138694d16 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4c1c190afe9d7252c592107138694d16&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4c1c190afe9d7252c592107138694d16 = L.map(
#                 &quot;map_4c1c190afe9d7252c592107138694d16&quot;,
#                 {
#                     center: [52.0, 9.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a22e0bfccc45b28951ca54b6e1f70c39 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a22e0bfccc45b28951ca54b6e1f70c39.addTo(map_4c1c190afe9d7252c592107138694d16);
#
#
#             var marker_89d003a9d563d7c2e14f34660e7a54ad = L.marker(
#                 [52.51767, 13.405538],
#                 {}
#             ).addTo(map_4c1c190afe9d7252c592107138694d16);
#
#
#             marker_89d003a9d563d7c2e14f34660e7a54ad.bindTooltip(
#                 `&lt;div&gt;
#                      Berlin, Stadt&lt;br&gt;Size: 3755251&lt;br&gt;Density: 4214
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8be15a77021844cec8484afa5b1703c2 = L.marker(
#                 [53.550678, 9.99697],
#                 {}
#             ).addTo(map_4c1c190afe9d7252c592107138694d16);
#
#
#             marker_8be15a77021844cec8484afa5b1703c2.bindTooltip(
#                 `&lt;div&gt;
#                      Hamburg, Freie und Hansestadt&lt;br&gt;Size: 1892122&lt;br&gt;Density: 2506
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3cfe25a7dc1dea3b9d2f13ef4f1c7b2d = L.marker(
#                 [48.137683, 11.575997],
#                 {}
#             ).addTo(map_4c1c190afe9d7252c592107138694d16);
#
#
#             marker_3cfe25a7dc1dea3b9d2f13ef4f1c7b2d.bindTooltip(
#                 `&lt;div&gt;
#                      München, Landeshauptstadt&lt;br&gt;Size: 1512491&lt;br&gt;Density: 4868
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a99e4053831e75aabd97b0ec7072fd79 = L.marker(
#                 [50.938107, 6.957068],
#                 {}
#             ).addTo(map_4c1c190afe9d7252c592107138694d16);
#
#
#             marker_a99e4053831e75aabd97b0ec7072fd79.bindTooltip(
#                 `&lt;div&gt;
#                      Köln, Stadt&lt;br&gt;Size: 1084831&lt;br&gt;Density: 2678
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2337225338caafa5e3e0bdb29629b342 = L.marker(
#                 [50.11088, 8.682433],
#                 {}
#             ).addTo(map_4c1c190afe9d7252c592107138694d16);
#
#
#             marker_2337225338caafa5e3e0bdb29629b342.bindTooltip(
#                 `&lt;div&gt;
#                      Frankfurt am Main, Stadt&lt;br&gt;Size: 773068&lt;br&gt;Density: 3113
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c20c2903eabb9b506951df906f09bb62 = L.marker(
#                 [48.775817, 9.177734],
#                 {}
#             ).addTo(map_4c1c190afe9d7252c592107138694d16);
#
#
#             marker_c20c2903eabb9b506951df906f09bb62.bindTooltip(
#                 `&lt;div&gt;
#                      Stuttgart, Landeshauptstadt&lt;br&gt;Size: 632865&lt;br&gt;Density: 3052
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f5325715283db6146ced5ba43679b34d = L.marker(
#                 [51.22422, 6.780068],
#                 {}
#             ).addTo(map_4c1c190afe9d7252c592107138694d16);
#
#
#             marker_f5325715283db6146ced5ba43679b34d.bindTooltip(
#                 `&lt;div&gt;
#                      Düsseldorf, Stadt&lt;br&gt;Size: 629047&lt;br&gt;Density: 2893
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_298ac6a45c366271890419e619fe0f96 = L.marker(
#                 [51.338288, 12.377931],
#                 {}
#             ).addTo(map_4c1c190afe9d7252c592107138694d16);
#
#
#             marker_298ac6a45c366271890419e619fe0f96.bindTooltip(
#                 `&lt;div&gt;
#                      Leipzig, Stadt&lt;br&gt;Size: 616093&lt;br&gt;Density: 2069
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e5bed77448a31f7808cd679c2584a3a0 = L.marker(
#                 [51.514171, 7.464165],
#                 {}
#             ).addTo(map_4c1c190afe9d7252c592107138694d16);
#
#
#             marker_e5bed77448a31f7808cd679c2584a3a0.bindTooltip(
#                 `&

# %%
# Close the connection to swat
cas.close()
