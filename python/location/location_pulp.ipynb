# %% [markdown]
# # Facility Location with Regions
#
# Based on Example 14.3 from the SAS Optimization documentation: https://go.documentation.sas.com/doc/en/pgmsascdc/default/casmopt/casmopt_milpsolver_examples03.htm
#
# For a set of customers and sites, choose which sites to build such that:
# - We minimize the sum of the distances between customers and their assigned sites and the building costs of sites
# - The capacity for each site is not exceeded
# - Sites and customers are in same region

# %% [markdown]
# #### Mixed Integer Linear Programming Formulation
#
# $ \begin{array}{llllll}
# \min & \displaystyle \sum _{i \in L} \displaystyle \sum _{j \in F} c_{ij} x_{ij} &+& \displaystyle \sum _{j \in F} f_ j y_ j \\
# \text{s.t.} & \displaystyle \sum _{j \in F} x_{ij} & = & 1 & \forall i \in L & \text{(assign\_def)} \\
# & \displaystyle \sum _{i \in L} d_ i x_{ij} & \leq & Cy_ j & \forall j \in F & \text{(capacity)} \\
# & x_{ij} & = & 0 & \forall i,j \text{ if } r_i \ne r_j & \text{(region\_con)} \\
# \\
# & \displaystyle \sum _{j \in F} f_ j y_ j &\le& B & \text{(budget\_con)}\\
# \\
# & x_{ij} \in \{ 0,1\} & & & \forall i \in L, j \in F \\
# & y_{j} \in \{ 0,1\} & & & \forall j \in F
# \end{array}
# $

# %% [markdown]
# #### Input Data
#
# For the input data we have a comma-separated value (CSV) file with all cities in Germany with more than 50,000 inhabitants retrieved from the German Federal Office of Statistics (www.destatis.de) that also includes geo locations of the cities for plotting. The following code reads the file and plots the data on a map.

# %%
import folium
import pandas as pd

# Read the input data and make sure the numbers are all parsed correctly, then print the top of the DataFrame
indata = pd.read_csv('cities_germany.csv', sep=';', decimal=',')
indata["size"] = pd.to_numeric(indata["size"].str.replace(" ", ""), errors='coerce')
indata["density"] = pd.to_numeric(indata["density"].str.replace(" ", ""), errors='coerce')
print(indata)

# Display the cities on a map of Germany
map_input = folium.Map(location=(52, 9), zoom_start=6)
for index, row in indata.iterrows():
    folium.Marker(location=[row["lat"], row["lon"]], tooltip=f'{row["name"]}<br>Size: {row["size"]}<br>Density: {row["density"]}').add_to(map_input)
    
map_input
# Out:
#      state                            name     size  density  zipcode  \
# 0       11                   Berlin, Stadt  3755251     4214    10178
# 1        2   Hamburg, Freie und Hansestadt  1892122     2506    20095
# 2        9       München, Landeshauptstadt  1512491     4868    80331
# 3        5                     Köln, Stadt  1084831     2678    50667
# 4        6        Frankfurt am Main, Stadt   773068     3113    60311
# ..     ...                             ...      ...      ...      ...
# 190      1                 Elmshorn, Stadt    50772     2377    25335
# 191      3                    Emden, Stadt    50535      450    26721
# 192      3                   Goslar, Stadt    50203      306    38640
# 193      5                  Willich, Stadt    50144      740    47877
# 194      8  Heidenheim an der Brenz, Stadt    50025      467    89522
#
#            lon        lat  type
# 0    13.405538  52.517670     1
# 1     9.996970  53.550678     1
# 2    11.575997  48.137683     1
# 3     6.957068  50.938107     1
# 4     8.682433  50.110880     1
# ..         ...        ...   ...
# 190   9.655259  53.754958     2
# 191   7.205946  53.370558     2
# 192  10.429312  51.906508     2
# 193   6.550043  51.262542     2
# 194  10.154639  48.677736     2
#
# [195 rows x 8 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a3235c1b93a23321493eaf39c329fc7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a3235c1b93a23321493eaf39c329fc7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a3235c1b93a23321493eaf39c329fc7 = L.map(
#                 &quot;map_2a3235c1b93a23321493eaf39c329fc7&quot;,
#                 {
#                     center: [52.0, 9.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4594c9cc04e9e0cb49c6ece5b7fda014 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4594c9cc04e9e0cb49c6ece5b7fda014.addTo(map_2a3235c1b93a23321493eaf39c329fc7);
#
#
#             var marker_6dcd20103de6f550976158d3f53e3c6d = L.marker(
#                 [52.51767, 13.405538],
#                 {}
#             ).addTo(map_2a3235c1b93a23321493eaf39c329fc7);
#
#
#             marker_6dcd20103de6f550976158d3f53e3c6d.bindTooltip(
#                 `&lt;div&gt;
#                      Berlin, Stadt&lt;br&gt;Size: 3755251&lt;br&gt;Density: 4214
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_058308c36615e0247c1f5291bf405f1d = L.marker(
#                 [53.550678, 9.99697],
#                 {}
#             ).addTo(map_2a3235c1b93a23321493eaf39c329fc7);
#
#
#             marker_058308c36615e0247c1f5291bf405f1d.bindTooltip(
#                 `&lt;div&gt;
#                      Hamburg, Freie und Hansestadt&lt;br&gt;Size: 1892122&lt;br&gt;Density: 2506
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e9fda5f90cd987bd09a249b0610057d6 = L.marker(
#                 [48.137683, 11.575997],
#                 {}
#             ).addTo(map_2a3235c1b93a23321493eaf39c329fc7);
#
#
#             marker_e9fda5f90cd987bd09a249b0610057d6.bindTooltip(
#                 `&lt;div&gt;
#                      München, Landeshauptstadt&lt;br&gt;Size: 1512491&lt;br&gt;Density: 4868
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_849f9b42c9bb7b0f4b12576d22dbacae = L.marker(
#                 [50.938107, 6.957068],
#                 {}
#             ).addTo(map_2a3235c1b93a23321493eaf39c329fc7);
#
#
#             marker_849f9b42c9bb7b0f4b12576d22dbacae.bindTooltip(
#                 `&lt;div&gt;
#                      Köln, Stadt&lt;br&gt;Size: 1084831&lt;br&gt;Density: 2678
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d4fe58e012779797a855b3032b304849 = L.marker(
#                 [50.11088, 8.682433],
#                 {}
#             ).addTo(map_2a3235c1b93a23321493eaf39c329fc7);
#
#
#             marker_d4fe58e012779797a855b3032b304849.bindTooltip(
#                 `&lt;div&gt;
#                      Frankfurt am Main, Stadt&lt;br&gt;Size: 773068&lt;br&gt;Density: 3113
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_57f2225296199cd5c88c77f859468ba4 = L.marker(
#                 [48.775817, 9.177734],
#                 {}
#             ).addTo(map_2a3235c1b93a23321493eaf39c329fc7);
#
#
#             marker_57f2225296199cd5c88c77f859468ba4.bindTooltip(
#                 `&lt;div&gt;
#                      Stuttgart, Landeshauptstadt&lt;br&gt;Size: 632865&lt;br&gt;Density: 3052
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_48fb83d9308a03c75f92ec8110909741 = L.marker(
#                 [51.22422, 6.780068],
#                 {}
#             ).addTo(map_2a3235c1b93a23321493eaf39c329fc7);
#
#
#             marker_48fb83d9308a03c75f92ec8110909741.bindTooltip(
#                 `&lt;div&gt;
#                      Düsseldorf, Stadt&lt;br&gt;Size: 629047&lt;br&gt;Density: 2893
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_742746c41163adff398ad054538467c1 = L.marker(
#                 [51.338288, 12.377931],
#                 {}
#             ).addTo(map_2a3235c1b93a23321493eaf39c329fc7);
#
#
#             marker_742746c41163adff398ad054538467c1.bindTooltip(
#                 `&lt;div&gt;
#                      Leipzig, Stadt&lt;br&gt;Size: 616093&lt;br&gt;Density: 2069
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5fe8dc249863b7e22072f7dbeb509658 = L.marker(
#                 [51.514171, 7.464165],
#                 {}
#             ).addTo(map_2a3235c1b93a23321493eaf39c329fc7);
#
#
#             marker_5fe8dc249863b7e22072f7dbeb509658.bindTooltip(
#                 `&

# %% [markdown]
# #### Defining the Optimization Problem with PuLP
#
# In this specific example, every customer location (city) can also be a site. The demand of each city is its size while we use the density as the cost to build a site. This means that building a site in a less densely populated cities is preferable. This leads to an interesting optimization problem for demonstration purposes but has no real-world meaning.
#
# The code below defines the optimization problem and connects it with the data.

# %%
from pulp import *
from geopy.distance import geodesic

# Input data
C = 5000000
SITES = indata.index.tolist()
lat = indata["lat"]
lon = indata["lon"]
demand = indata["size"]
cost = indata["density"]
region = indata["state"]
PAIRS = [(i, j) for i in SITES for j in SITES]
dist = pd.DataFrame(
    [
        [i, j, round(geodesic((lat[i], lon[i]),(lat[j], lon[j])).km)]
        for (i, j) in PAIRS
    ],
    columns=["i", "j", "dist"],
).set_index(["i", "j"])["dist"]

prob = LpProblem("location", LpMinimize)

# Define the variables
Build = LpVariable.dicts("Build site", SITES, 0, 1, LpBinary)
Assign = LpVariable.dicts("Assign customer to site", PAIRS, 0, 1, LpBinary)

# Define objective function
prob += lpSum(dist[i, j] * Assign[i, j] for (i, j) in PAIRS) + lpSum(cost[j] * Build[j] for j in SITES)

# Define assign_df constraints
for t in SITES:
    prob += lpSum(Assign[i, j] for (i, j) in PAIRS if i == t) == 1

# Define capacity constraints
for t in SITES:
    prob += lpSum(demand[i] * Assign[i, j] for (i, j) in PAIRS if j == t) <= C * Build[t]

# %% [markdown]
# Solve the problem using the SAS solver.

# %%
from cas import cas_options

sas_solver = SASCAS(casOptions=cas_options)
_ = prob.solve(sas_solver)
# Out:
# NOTE: Added action set 'optimization'.
# NOTE: The problem location has 38220 variables (38220 binary, 0 integer, 0 free, 0 fixed).
# NOTE: The problem has 390 constraints (195 LE, 195 EQ, 0 GE, 0 range).
# NOTE: The problem has 76245 constraint coefficients.
# NOTE: The initial MILP heuristics are applied.
# NOTE: The MILP presolver value AUTOMATIC is applied.
# NOTE: The MILP presolver removed 0 variables and 0 constraints.
# NOTE: The MILP presolver removed 0 constraint coefficients.
# NOTE: The MILP presolver modified 0 constraint coefficients.
# NOTE: The presolved problem has 38220 variables, 390 constraints, and 76245 constraint coefficients.
# NOTE: The MILP solver is called.
# NOTE: The parallel Branch and Cut algorithm is used.
# NOTE: The Branch and Cut algorithm is using up to 16 threads.
#          Node   Active   Sols    BestInteger      BestBound      Gap    Time
#                 0        1      5  71451.0000000              0    71451       0
#                 0        1      5  71451.0000000   6371.5284122 1021,41%       0
#                 0        1      5  71451.0000000   9860.1155393  624,65%       1
#                 0        1      7  38973.0000000   9860.1155393  295,26%       1
#                 0        1      7  38973.0000000  11551.7997412  237,38%       1
#                 0        1      7  38973.0000000  12753.0752806  205,60%       1
#                 0        1      7  38973.0000000  13772.6545028  182,97%       2
#                 0        1      7  38973.0000000  14555.4671617  167,76%       2
#                 0        1      7  38973.0000000  15183.5131441  156,68%       3
#                 0        1      7  38973.0000000  15649.4221777  149,04%       3
#                 0        1      7  38973.0000000  15938.0785444  144,53%       4
#                 0        1      7  38973.0000000  16196.4633287  140,63%       4
#                 0        1      7  38973.0000000  16365.0102798  138,15%       5
#                 0        1      7  38973.0000000  16498.3234054  136,22%       6
#                 0        1      7  38973.0000000  16599.6381989  134,78%       6
#                 0        1      7  38973.0000000  16679.1512480  133,66%       7
#                 0        1      7  38973.0000000  16737.8022080  132,84%       7
#                 0        1      7  38973.0000000  16791.8081728  132,10%       8
#                 0        1      7  38973.0000000  16834.3335337  131,51%       8
#                 0        1      7  38973.0000000  16861.3563220  131,14%       9
#                 0        1      7  38973.0000000  16884.3571274  130,82%       9
#                 0        1      7  38973.0000000  16896.9809692  130,65%      10
#                 0        1      7  38973.0000000  16906.6451868  130,52%      10
#                 0        1      7  38973.0000000  16914.0018569  130,42%      10
#                 0        1      7  38973.0000000  16914.9442358  130,41%      10
#                 0        1      7  38973.0000000  16919.5517076  130,34%      11
#                 0        1      7  38973.0000000  16921.5320967  130,32%      11
# NOTE: The MILP solver added 1607 cuts with 3576 cut coefficients at the root.
#                 5        6      8  25396.0000000  16921.5320967   50,08%      13
#                29       23      9  24898.0000000  16922.9906992   47,13%      14
#                46       32     12  23972.0000000  16923.8857209   41,65%      14
#                87       73     12  23972.0000000  16923.8857209   41,65%      15
#               113       92     13  18874.0000000  16923.8857209   11,52%      15
#               150      125     15  18168.0000000  16923.9133426    7,35%      15
#               172       32     16  17349.0000000  16930.2020798    2,47%      16
#               181       15     17  17310.0011776  16930.3098222    2,24%      16
#               183       16     18  17173.0011518  16930.3098222    1,43%      16
#               188       11     20  17053.0011524  16931.5860456    0,72%      16
#               189        0     21  16932.0011304  16932.0011304    0,00%      16
# NOTE: Optimal.
# NOTE: Objective = 16932,00113.

# %% [markdown]
# The following code computes the parts of the objective from the output data sets to see how long the total distance between sites and customers is compared to the fixed charge building costs of the sites.

# %%
assignments = pd.DataFrame([(lat[i], lon[i], lat[j], lon[j], dist[i,j]) 
                            for (i,j) in PAIRS if Assign[i,j].varValue > 0.5],
                            columns=["lat1", "lon1", "lat2", "lon2","distance" ]
                            )

sites = pd.DataFrame([(indata["name"][j], lat[j], lon[j], cost[j]) 
                      for j in SITES if Build[j].varValue > 0.5],
                      columns=["name", "lat", "lon","cost" ]
                    )

# Print the sum of the distances
total_distance = assignments["distance"].sum()
print(f"Total distance: {total_distance}")

## Print the sum of the building costs
total_site_cost = sites["cost"].sum()
print(f"Total site cost: {total_site_cost}")

print(f"Objective: {total_distance + total_site_cost}")
# Out:
# Total distance: 11735
# Total site cost: 5197
# Objective: 16932

# %% [markdown]
# Now display the map with the solution.

# %%
map_noregion = folium.Map(location=(52, 9), zoom_start=6)

# Plot all cities
for index, row in indata.iterrows():
    folium.Marker(location=[row["lat"], row["lon"]], tooltip=f'{row["name"]}<br>Size: {row["size"]}<br>Density: {row["density"]}').add_to(map_noregion)

# Plot the cities that are sites to build
for index, row in sites.iterrows():
    folium.Marker(location=[row["lat"], row["lon"]], tooltip=row["name"], icon=folium.Icon(color="green")).add_to(map_noregion)

# Plot the assignments of customers to sites
for idx, row in assignments.iterrows():
    folium.PolyLine([[row["lat1"], row["lon1"]],
                     [row["lat2"], row["lon2"]]]).add_to(map_noregion)

map_noregion
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2491e56dcebe6cb49e5968c4af81bc2e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2491e56dcebe6cb49e5968c4af81bc2e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2491e56dcebe6cb49e5968c4af81bc2e = L.map(
#                 &quot;map_2491e56dcebe6cb49e5968c4af81bc2e&quot;,
#                 {
#                     center: [52.0, 9.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b3e2026b322c242fe2d330f6372a0abb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b3e2026b322c242fe2d330f6372a0abb.addTo(map_2491e56dcebe6cb49e5968c4af81bc2e);
#
#
#             var marker_e4e955e97405bb8a68be8c69e0754e34 = L.marker(
#                 [52.51767, 13.405538],
#                 {}
#             ).addTo(map_2491e56dcebe6cb49e5968c4af81bc2e);
#
#
#             marker_e4e955e97405bb8a68be8c69e0754e34.bindTooltip(
#                 `&lt;div&gt;
#                      Berlin, Stadt&lt;br&gt;Size: 3755251&lt;br&gt;Density: 4214
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_708ac18a0365afb475a11570459064af = L.marker(
#                 [53.550678, 9.99697],
#                 {}
#             ).addTo(map_2491e56dcebe6cb49e5968c4af81bc2e);
#
#
#             marker_708ac18a0365afb475a11570459064af.bindTooltip(
#                 `&lt;div&gt;
#                      Hamburg, Freie und Hansestadt&lt;br&gt;Size: 1892122&lt;br&gt;Density: 2506
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ef3e604266f46a40b67d1dbd31145a35 = L.marker(
#                 [48.137683, 11.575997],
#                 {}
#             ).addTo(map_2491e56dcebe6cb49e5968c4af81bc2e);
#
#
#             marker_ef3e604266f46a40b67d1dbd31145a35.bindTooltip(
#                 `&lt;div&gt;
#                      München, Landeshauptstadt&lt;br&gt;Size: 1512491&lt;br&gt;Density: 4868
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_713092fff3a204b5993df0cab68b50ee = L.marker(
#                 [50.938107, 6.957068],
#                 {}
#             ).addTo(map_2491e56dcebe6cb49e5968c4af81bc2e);
#
#
#             marker_713092fff3a204b5993df0cab68b50ee.bindTooltip(
#                 `&lt;div&gt;
#                      Köln, Stadt&lt;br&gt;Size: 1084831&lt;br&gt;Density: 2678
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5b1635678b3eabcae72b4b473beb4938 = L.marker(
#                 [50.11088, 8.682433],
#                 {}
#             ).addTo(map_2491e56dcebe6cb49e5968c4af81bc2e);
#
#
#             marker_5b1635678b3eabcae72b4b473beb4938.bindTooltip(
#                 `&lt;div&gt;
#                      Frankfurt am Main, Stadt&lt;br&gt;Size: 773068&lt;br&gt;Density: 3113
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d91d5255d182ef85dd5998059362c76b = L.marker(
#                 [48.775817, 9.177734],
#                 {}
#             ).addTo(map_2491e56dcebe6cb49e5968c4af81bc2e);
#
#
#             marker_d91d5255d182ef85dd5998059362c76b.bindTooltip(
#                 `&lt;div&gt;
#                      Stuttgart, Landeshauptstadt&lt;br&gt;Size: 632865&lt;br&gt;Density: 3052
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_623d0d306e3d4a1e103020cc65ec71a6 = L.marker(
#                 [51.22422, 6.780068],
#                 {}
#             ).addTo(map_2491e56dcebe6cb49e5968c4af81bc2e);
#
#
#             marker_623d0d306e3d4a1e103020cc65ec71a6.bindTooltip(
#                 `&lt;div&gt;
#                      Düsseldorf, Stadt&lt;br&gt;Size: 629047&lt;br&gt;Density: 2893
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7bb49a6366141af8daf8fe549837e71c = L.marker(
#                 [51.338288, 12.377931],
#                 {}
#             ).addTo(map_2491e56dcebe6cb49e5968c4af81bc2e);
#
#
#             marker_7bb49a6366141af8daf8fe549837e71c.bindTooltip(
#                 `&lt;div&gt;
#                      Leipzig, Stadt&lt;br&gt;Size: 616093&lt;br&gt;Density: 2069
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b7eb4a79dc8a1acbbe11fc10f71ec831 = L.marker(
#                 [51.514171, 7.464165],
#                 {}
#             ).addTo(map_2491e56dcebe6cb49e5968c4af81bc2e);
#
#
#             marker_b7eb4a79dc8a1acbbe11fc10f71ec831.bindTooltip(
#                 `&

# %% [markdown]
# #### Modify the Example to Respect Regions
#
# The following code we redefine the `PAIRS` set and those parts of the model that rely on it to only allow assignments within regions.

# %%
PAIRS = [(i, j) for i in SITES for j in SITES if region[i] == region[j]]

prob = LpProblem("location_region", LpMinimize)

# Define the variables
Build = LpVariable.dicts("Build site", SITES, 0, 1, LpBinary)
Assign = LpVariable.dicts("Assign customer to site", PAIRS, 0, 1, LpBinary)

# Define objective function
prob += lpSum(dist[i, j] * Assign[i, j] for (i, j) in PAIRS) + lpSum(cost[j] * Build[j] for j in SITES)

# Define assign_df constraints
for t in SITES:
    prob += lpSum(Assign[i, j] for (i, j) in PAIRS if i == t) == 1

# Define capacity constraints
for t in SITES:
    prob += lpSum(demand[i] * Assign[i, j] for (i, j) in PAIRS if j == t) <= C * Build[t]

# Solve the problem
_ = prob.solve(sas_solver)
# Out:
# NOTE: Added action set 'optimization'.
# NOTE: The problem location_region has 7766 variables (7766 binary, 0 integer, 0 free, 0 fixed).
# NOTE: The problem has 390 constraints (195 LE, 195 EQ, 0 GE, 0 range).
# NOTE: The problem has 15337 constraint coefficients.
# NOTE: The initial MILP heuristics are applied.
# NOTE: The MILP presolver value AUTOMATIC is applied.
# NOTE: The MILP presolver removed 8 variables and 8 constraints.
# NOTE: The MILP presolver removed 13 constraint coefficients.
# NOTE: The MILP presolver modified 116 constraint coefficients.
# NOTE: The presolved problem has 7758 variables, 382 constraints, and 15324 constraint coefficients.
# NOTE: The MILP solver is called.
# NOTE: The parallel Branch and Cut algorithm is used.
# NOTE: The Branch and Cut algorithm is using up to 16 threads.
# NOTE: The problem has a decomposable structure with 13 blocks. The largest block covers 39,79% of the constraints in the problem.
#          Node   Active   Sols    BestInteger      BestBound      Gap    Time
#                 0        1      6  36929.0000000   7806.0000000  373,08%       0
#                 0        1      6  36929.0000000  20561.1896813   79,61%       0
#                 0        1      6  36929.0000000  25945.5711534   42,33%       0
# NOTE: The MILP presolver is applied again.
#                 0        1      7  31040.0000000  25945.5711534   19,64%       0
#                 0        1      7  31040.0000000  26643.4738558   16,50%       0
#                 0        1      7  31040.0000000  27041.8517936   14,79%       0
#                 0        1      7  31040.0000000  27227.5363817   14,00%       0
#                 0        1      7  31040.0000000  27405.6595588   13,26%       0
#                 0        1      7  31040.0000000  27523.0677931   12,78%       1
#                 0        1      7  31040.0000000  27638.8399335   12,31%       1
#                 0        1      7  31040.0000000  27722.6284800   11,97%       1
#                 0        1      7  31040.0000000  27821.1001893   11,57%       1
#                 0        1      7  31040.0000000  27892.7628272   11,28%       1
#                 0        1      7  31040.0000000  27971.1654946   10,97%       1
#                 0        1      7  31040.0000000  28014.9838092   10,80%       2
#                 0        1      7  31040.0000000  28033.1030766   10,73%       2
#                 0        1      7  31040.0000000  28041.4361346   10,69%       2
#                 0        1      7  31040.0000000  28049.3574876   10,66%       2
#                 0        1      7  31040.0000000  28055.6259847   10,64%       2
#                 0        1      7  31040.0000000  28059.5955447   10,62%       2
#                 0        1      7  31040.0000000  28063.8621356   10,60%       2
#                 0        1     10  29870.0000000  28063.8621356    6,44%       2
#                 0        1     10  29870.0000000  28066.7572162    6,42%       2
#                 0        1     13  28553.0000000  28066.7572162    1,73%       2
#                 0        1     13  28553.0000000  28069.8697704    1,72%       3
# NOTE: The MILP presolver is applied again.
#                 0        1     14  28403.0000000  28069.8697704    1,19%       3
#                 0        1     14  28403.0000000  28069.8697704    1,19%       3
#                 0        1     14  28403.0000000  28069.8697704    1,19%       3
#                 0        1     14  28403.0000000  28069.8697704    1,19%       3
#                 0        1     14  28403.0000000  28069.8697704    1,19%       3
#                 0        1     14  28403.0000000  28069.8697704    1,19%       3
#                 0        1     14  28403.0000000  28069.8697704    1,19%       3
#                 0        1     14  28403.0000000  28069.8697704    1,19%       3
#                 0        1     14  28403.0000000  28069.8697704    1,19%       3
#                 0        1     14  28403.0000000  28069.8697704    1,19%       3
# NOTE: The MILP presolver is applied again.
#                 0        1     14  28403.0000000  28069.8697704    1,19%       3
#                 0        1     14  28403.0000000  28069.8697704    1,19%       3
#                 0        1     14  28403.0000000  28069.8697704    1,19%       3
#                 0        1     14  28403.0000000  28069.8697704    1,19%       4
#                 0        1     14  28403.0000000  28069.8697704    1,19%       4
#                 0        1     14  28403.0000000  28069.8697704    1,19%       4
#                 0        1     14  28403.0000000  28069.8697704    1,19%       4
#                 0        1     14  28403.0000000  28069.8697704    1,19%       4
#                 0        1     14  28403.0000000  28069.8697704    1,19%       4
#                 0        1     14  28403.0000000  28069.8697704    1,19%       4
# NOTE: The MILP solver added 532 cuts with 5511 cut coefficients at the root.
# NOTE: Optimal within relative gap.
# NOTE: Objective = 28072.

# %% [markdown]
# Print the objective for the modified problem.

# %%
assignments = pd.DataFrame([(lat[i], lon[i], lat[j], lon[j], dist[i,j]) 
                            for (i,j) in PAIRS if Assign[i,j].varValue > 0.5],
                            columns=["lat1", "lon1", "lat2", "lon2","distance" ]
                            )

sites = pd.DataFrame([(indata["name"][j], lat[j], lon[j], cost[j]) 
                      for j in SITES if Build[j].varValue > 0.5],
                      columns=["name", "lat", "lon","cost" ]
                    )

# Print the sum of the distances
total_distance = assignments["distance"].sum()
print(f"Total distance: {total_distance}")

## Print the sum of the building costs
total_site_cost = sites["cost"].sum()
print(f"Total site cost: {total_site_cost}")

print(f"Objective: {total_distance + total_site_cost}")
# Out:
# Total distance: 9970
# Total site cost: 18102
# Objective: 28072

# %% [markdown]
# Display the map for the modified problem where regions are respected. Note that Berlin, Hamburg, and Saarbrücken have to be sites now since they are the only possible sites in their regions. Bremen chooses Bremerhaven as the site in the state of Bremen (which might or might not be a valid decision to make).

# %%
map_region = folium.Map(location=(52, 9), zoom_start=6)

# Plot all cities
for index, row in indata.iterrows():
    folium.Marker(location=[row["lat"], row["lon"]], tooltip=f'{row["name"]}<br>Size: {row["size"]}<br>Density: {row["density"]}').add_to(map_region)

# Plot the cities that are sites to build
for index, row in sites.iterrows():
    folium.Marker(location=[row["lat"], row["lon"]], tooltip=row["name"], icon=folium.Icon(color="green")).add_to(map_region)

# Plot the assignments of customers to sites
for idx, row in assignments.iterrows():
    folium.PolyLine([[row["lat1"], row["lon1"]],
                     [row["lat2"], row["lon2"]]]).add_to(map_region)

map_region
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_21dd833a68ef3374ae193f609a6395d0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_21dd833a68ef3374ae193f609a6395d0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_21dd833a68ef3374ae193f609a6395d0 = L.map(
#                 &quot;map_21dd833a68ef3374ae193f609a6395d0&quot;,
#                 {
#                     center: [52.0, 9.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_30ecd26161b580fd5d8948cdcda29632 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_30ecd26161b580fd5d8948cdcda29632.addTo(map_21dd833a68ef3374ae193f609a6395d0);
#
#
#             var marker_9dc964541ad3c368e3644f6cf0e6cec5 = L.marker(
#                 [52.51767, 13.405538],
#                 {}
#             ).addTo(map_21dd833a68ef3374ae193f609a6395d0);
#
#
#             marker_9dc964541ad3c368e3644f6cf0e6cec5.bindTooltip(
#                 `&lt;div&gt;
#                      Berlin, Stadt&lt;br&gt;Size: 3755251&lt;br&gt;Density: 4214
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6e61b43b7c342b139f3eceabf941f208 = L.marker(
#                 [53.550678, 9.99697],
#                 {}
#             ).addTo(map_21dd833a68ef3374ae193f609a6395d0);
#
#
#             marker_6e61b43b7c342b139f3eceabf941f208.bindTooltip(
#                 `&lt;div&gt;
#                      Hamburg, Freie und Hansestadt&lt;br&gt;Size: 1892122&lt;br&gt;Density: 2506
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_661bb470b56ed71df8f568eb1c0d7f32 = L.marker(
#                 [48.137683, 11.575997],
#                 {}
#             ).addTo(map_21dd833a68ef3374ae193f609a6395d0);
#
#
#             marker_661bb470b56ed71df8f568eb1c0d7f32.bindTooltip(
#                 `&lt;div&gt;
#                      München, Landeshauptstadt&lt;br&gt;Size: 1512491&lt;br&gt;Density: 4868
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a782b8812b172a24bc0b04e714d1fef6 = L.marker(
#                 [50.938107, 6.957068],
#                 {}
#             ).addTo(map_21dd833a68ef3374ae193f609a6395d0);
#
#
#             marker_a782b8812b172a24bc0b04e714d1fef6.bindTooltip(
#                 `&lt;div&gt;
#                      Köln, Stadt&lt;br&gt;Size: 1084831&lt;br&gt;Density: 2678
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0b065bc690ca0f71ea4e6862bfcd7688 = L.marker(
#                 [50.11088, 8.682433],
#                 {}
#             ).addTo(map_21dd833a68ef3374ae193f609a6395d0);
#
#
#             marker_0b065bc690ca0f71ea4e6862bfcd7688.bindTooltip(
#                 `&lt;div&gt;
#                      Frankfurt am Main, Stadt&lt;br&gt;Size: 773068&lt;br&gt;Density: 3113
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_624ac790cabbf9842edeb7442c9be27d = L.marker(
#                 [48.775817, 9.177734],
#                 {}
#             ).addTo(map_21dd833a68ef3374ae193f609a6395d0);
#
#
#             marker_624ac790cabbf9842edeb7442c9be27d.bindTooltip(
#                 `&lt;div&gt;
#                      Stuttgart, Landeshauptstadt&lt;br&gt;Size: 632865&lt;br&gt;Density: 3052
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ed6c43a337c4a6f4e8e42edd7330eba3 = L.marker(
#                 [51.22422, 6.780068],
#                 {}
#             ).addTo(map_21dd833a68ef3374ae193f609a6395d0);
#
#
#             marker_ed6c43a337c4a6f4e8e42edd7330eba3.bindTooltip(
#                 `&lt;div&gt;
#                      Düsseldorf, Stadt&lt;br&gt;Size: 629047&lt;br&gt;Density: 2893
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_883497d2868988aea4f1ea45b395d755 = L.marker(
#                 [51.338288, 12.377931],
#                 {}
#             ).addTo(map_21dd833a68ef3374ae193f609a6395d0);
#
#
#             marker_883497d2868988aea4f1ea45b395d755.bindTooltip(
#                 `&lt;div&gt;
#                      Leipzig, Stadt&lt;br&gt;Size: 616093&lt;br&gt;Density: 2069
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_74bfa9f123d7a86ed8ce0045f1002e51 = L.marker(
#                 [51.514171, 7.464165],
#                 {}
#             ).addTo(map_21dd833a68ef3374ae193f609a6395d0);
#
#
#             marker_74bfa9f123d7a86ed8ce0045f1002e51.bindTooltip(
#                 `&

# %%
# Clean up the SAS connection
del(sas_solver)
